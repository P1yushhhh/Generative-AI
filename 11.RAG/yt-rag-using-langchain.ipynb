# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate

# %% [markdown]
# ### Step 1a - Indexing (Document Ingestion)

# %%
video_id = "xt5Z0CBP2J4" # only the ID, not full URL

try:
    # If you don’t care which language, this returns the “best” one
    transcript_list = YouTubeTranscriptApi.get_transcript(video_id, languages=["en"])

    transcript = " ".join(chunk["text"] for chunk in transcript_list)
    print(transcript)
except TranscriptsDisabled:
    print("No Transcript available for this video")
# Out:
# They drizzled it all across. Is that the right word? Drizzled. Megan Fox just just emailed me. Sorry. Okay, we'll read it for the class. It's for a beep. It's for a beeper party. Anyway, um No, no, no, no, no. Now we need to know. That's You can't just leave that. You need to read that email. Just park that in the side and move on. Megan Fox. Is it the real Megan Fox or is it like Well, she is real. Yo, what is up people of the internet? Welcome back to another episode of the Waveform Podcast. We're your hosts. I'm Marquez. I'm Andrew. And I'm David. This was WWDC week. Apple had their uh their their software announcement festivities slash an what? I don't know what you want to call it. It's a developer conference, but it's also like unveiling a bunch of new stuff. Ragger. And uh yeah, there's there's lots to talk about. There's liquid glass. There is iPad turning into a computer finally. You guys are stuff. I didn't do anything. You didn't say it yet. Uh fake workout buddies. Everything's computer. Everything is a computer. Um lots of thoughts. This is the place where we give all of our thoughts. We've also you have you said you have the developer beta on everything. Everything. Okay, perfect. I've gotten some hands-on time with iOS, iPad OS, Mac OS, all these developer betas, the liquid glass across all of them. I have a a video I'll show you of my new scanned persona. Oh, from the Vision Pro. That got more interest than I thought it would. I'll show you guys the video first up. Um, let's do it. My new We're just going straight into it. Yeah, I'll show you. Subscribe if you want to see Marquez's new persona. What animal are you? This is my new uh your new high Vision OS. My Vision OS 26 persona realistic Moji. Okay. This is my new vision pro persona. That's what you just said. I feel like I'm looking in the mirror. Was this taken at like in a briefing? Resolution and better looking than So the textures are better. The face shape is not quite right. Your nose is very broad. Do your lips move. Your face is wider accurately. I think the skin tones and little subvariations in skin tone and texture are more accurate. And then the rest is about the same. Yeah. The face shape is like wider than your actual face. I think so. Yeah. Yeah. The cutout also reminds me of um what was the Google thing? Star Starline. Starline. It remember It reminds me of like Starline one cutout of like that's pretty good, but the more you look at it, the more blocky and like chopped off like old bad portrait mode. Yeah. Yeah. Wait, Marquez, could you drop that video in the Slack for the big ballers already uploading? Sweet. Yes. So, yeah, I guess we can we can talk about any number of these OSs. They are all labeled version 26 now. So if you were thinking, "Oh, this is only the third Vision OS." Oh, we know. It's just they call it Vision OS 26 now because they're all 26. We talked about this last week how it's feels futuristic even though it comes out during 2025. I mean, who doesn't want iOS 26 at WWDC2? Exactly. On the Galaxy S25 Ultra. Someone brought up an interesting point. Are they going to call the new iPhone the iPhone 26 now? cuz it's going to be a little awkward to have the iPhone 17 running iOS 26. They're going to call it the iPhone 9. Oh god. Well, we Well, it didn't match before though. Yeah. True. Yeah. I don't think they're going to. I don't think they will. Okay. So, I iPhone 17 iOS 26. We'll see. We should place this bet. No, we'll see. Uh yeah, I guess we'll start. Speaking of a bet. Yeah. What was our overunder last week for how many times they say? I think it was four 4.5 or something. and I said under. It turns out they said the word Siri times total during the entire 90minute presentation that main keynote. It was right off the riff and they it was right at the beginning and it was back to back and then they just didn't say the word again. They they like weirdly went here's all the things Apple intelligence brought and there was li ...

# %%
transcript_list
# Out:
# [{'text': 'They drizzled it all across. Is that the',
#   'start': 0.16,
#   'duration': 5.04},
#  {'text': 'right word? Drizzled.', 'start': 2.56, 'duration': 6.079},
#  {'text': 'Megan Fox just just emailed me.', 'start': 5.2, 'duration': 5.6},
#  {'text': 'Sorry.', 'start': 8.639, 'duration': 3.681},
#  {'text': "Okay, we'll read it for the class. It's",
#   'start': 10.8,
#   'duration': 3.28},
#  {'text': "for a beep. It's for a beeper party.",
#   'start': 12.32,
#   'duration': 4.799},
#  {'text': 'Anyway, um No, no, no, no, no. Now we',
#   'start': 14.08,
#   'duration': 4.24},
#  {'text': "need to know. That's You can't just",
#   'start': 17.119,
#   'duration': 2.881},
#  {'text': 'leave that. You need to read that email.',
#   'start': 18.32,
#   'duration': 3.2},
#  {'text': 'Just park that in the side and move on.',
#   'start': 20.0,
#   'duration': 3.68},
#  {'text': 'Megan Fox. Is it the real Megan Fox or',
#   'start': 21.52,
#   'duration': 7.32},
#  {'text': 'is it like Well, she is real.', 'start': 23.68, 'duration': 5.16},
#  {'text': 'Yo, what is up people of the internet?',
#   'start': 30.48,
#   'duration': 3.28},
#  {'text': 'Welcome back to another episode of the',
#   'start': 32.0,
#   'duration': 3.6},
#  {'text': "Waveform Podcast. We're your hosts. I'm",
#   'start': 33.76,
#   'duration': 4.24},
#  {'text': "Marquez. I'm Andrew. And I'm David. This",
#   'start': 35.6,
#   'duration': 5.68},
#  {'text': 'was WWDC week. Apple had their uh their',
#   'start': 38.0,
#   'duration': 6.0},
#  {'text': 'their software announcement festivities',
#   'start': 41.28,
#   'duration': 5.04},
#  {'text': "slash an what? I don't know what you",
#   'start': 44.0,
#   'duration': 3.68},
#  {'text': "want to call it. It's a developer",
#   'start': 46.32,
#   'duration': 3.12},
#  {'text': "conference, but it's also like unveiling",
#   'start': 47.68,
#   'duration': 3.92},
#  {'text': 'a bunch of new stuff. Ragger. And uh',
#   'start': 49.44,
#   'duration': 3.92},
#  {'text': "yeah, there's there's lots to talk",
#   'start': 51.6,
#   'duration': 3.92},
#  {'text': "about. There's liquid glass. There is",
#   'start': 53.36,
#   'duration': 4.4},
#  {'text': 'iPad turning into a computer finally.',
#   'start': 55.52,
#   'duration': 4.16},
#  {'text': "You guys are stuff. I didn't do",
#   'start': 57.76,
#   'duration': 4.959},
#  {'text': "anything. You didn't say it yet. Uh fake",
#   'start': 59.68,
#   'duration': 5.04},
#  {'text': "workout buddies. Everything's computer.",
#   'start': 62.719,
#   'duration': 4.321},
#  {'text': 'Everything is a computer. Um lots of',
#   'start': 64.72,
#   'duration': 3.84},
#  {'text': 'thoughts. This is the place where we',
#   'start': 67.04,
#   'duration': 3.28},
#  {'text': "give all of our thoughts. We've also you",
#   'start': 68.56,
#   'duration': 3.12},
#  {'text': 'have you said you have the developer',
#   'start': 70.32,
#   'duration': 4.08},
#  {'text': 'beta on everything. Everything. Okay,',
#   'start': 71.68,
#   'duration': 4.16},
#  {'text': "perfect. I've gotten some hands-on time",
#   'start': 74.4,
#   'duration': 4.48},
#  {'text': 'with iOS, iPad OS, Mac OS, all these',
#   'start': 75.84,
#   'duration': 4.72},
#  {'text': 'developer betas, the liquid glass across',
#   'start': 78.88,
#   'duration': 3.84},
#  {'text': "all of them. I have a a video I'll show",
#   'start': 80.56,
#   'duration': 6.0},
#  {'text': 'you of my new scanned persona. Oh, from',
#   'start': 82.72,
#   'duration': 5.439},
#  {'text': 'the Vision Pro. That got more interest',
#   'start': 86.56,
#   'duration': 4.16},
#  {'text': 'than I thought it would.', 'start': 88.159, 'duration': 4.241},
#  {'text': "I'll show you guys the video first up.",
#   'start': 90.72,
#   'duration': 3.68},
#  {'text': "Um, let's do it. My new We're just going",
#   'start': 92.4,
#   'duration': 3.44},
#  {'text': "straight into it. Yeah, I'll show you.",
#   'start': 94.4,
#   'duration': 3.44},
#  {'text': "Subscribe if you want to see Marquez's",
#   'start': 95.84,
#   'duration': 5.44},
#  {'text': 'new persona. What animal are you? This',
#   'start': 97.84,
#   'duration': 7.279},
#  {'text': 'is my new uh your new high Vision OS. My',
#   'start': 101.28,
#   'duration': 8.4},
#  {'text': 'Vision OS 26 persona realistic Moji.',
#   'start': 105.119,
#   'duration': 8.561},
#  {'text': 'Okay. This is my new vision pro persona.',
#   'start': 109.68,
#   'duration': 6.32},
#  {'text': "That's what you just said. I feel like",
#   'start': 113.68,
#   'duration': 4.079},
#  {'text': "I'm looking in the mirror. Was this",
#   'start': 116.0,
#   'duration': 4.0},
#  {'text': 'taken at like in a briefing? Resolution',
#   'start': 117.759,
#   'duration': 4.481},
#  {'text': 'and better looking than So the textures',
#   'start': 120.0,
#   'duration': 4.159},
#  {'text': 'are better. The face shape is not quite',
#   'start': 122.24,
#   'duration': 4.08},
#  {'text': 'right. Your nose is very broad. Do your',
#   'start': 124.159,
#   'duration': 3.761},
#  {'text': 'lips move. Your face is wider', 'start': 126.32, 'duration': 4.639},
#  {'text': 'accurately. I think the skin tones and',
#   'start': 127.92,
#   'duration': 5.679},
#  {'text': 'little subvariations in skin tone and',
#   'start': 130.959,
#   'duration': 5.441},
#  {'text': 'texture are more accurate. And then the',
#   'start': 133.599,
#   'duration': 4.881},
#  {'text': 'rest is about the same. Yeah. The face',
#   'start': 136.4,
#   'duration': 3.6},
#  {'text': 'shape is like wider than your actual',
#   'start': 138.48,
#   'duration': 4.08},
#  {'text': 'face. I think so. Yeah. Yeah. The cutout',
#   'start': 140.0,
#   'duration': 5.76},
#  {'text': 'also reminds me of um what was the',
#   'start': 142.56,
#   'duration': 6.08},
#  {'text': 'Google thing? Star Starline. Starline.',
#   'start': 145.76,
#   'duration': 4.24},
#  {'text': 'It remember It reminds me of like',
#   'start': 148.64,
#   'duration': 3.84},
#  {'text': "Starline one cutout of like that's",
#   'start': 150.0,
#   'duration': 3.44},
#  {'text': 'pretty good, but the more you look at',
#   'start': 152.48,
#   'duration': 3.2},
#  {'text': 'it, the more blocky and like chopped off',
#   'start': 153.44,
#   'duration': 4.799},
#  {'text': 'like old bad portrait mode. Yeah. Yeah.',
#   'start': 155.68,
#   'duration': 4.0},
#  {'text': 'Wait, Marquez, could you drop that video',
#   'start': 158.239,
#   'duration': 3.28},
#  {'text': 'in the Slack for the big ballers already',
#   'start': 159.68,
#   'duration': 4.639},
#  {'text': 'uploading? Sweet. Yes. So, yeah, I guess',
#   'start': 161.519,
#   'duration': 4.241},
#  {'text': 'we can we can talk about any number of',
#   'start': 164.319,
#   'duration': 3.92},
#  {'text': 'these OSs. They are all labeled version',
#   'start': 165.76,
#   'duration': 4.479},
#  {'text': '26 now. So if you were thinking, "Oh,',
#   'start': 168.239,
#   'duration': 3.681},
#  {'text': 'this is only the third Vision OS." Oh,',
#   'start': 170.239,
#   'duration': 3.121},
#  {'text': "we know. It's just they call it Vision",
#   'start': 171.92,
#   'duration': 4.319},
#  {'text': "OS 26 now because they're all 26. We",
#   'start': 173.36,
#   'duration': 4.8},
#  {'text': "talked about this last week how it's",
#   'start': 176.239,
#   'duration': 3.201},
#  {'text': 'feels futuristic even though it comes',
#   'start': 178.16,
#   'duration': 3.12},
#  {'text': "out during 2025. I mean, who doesn't",
#   'start': 179.44,
#   'duration': 5.04},
#  {'text': 'want iOS 26 at WWDC2?', 'start': 181.28, 'duration': 6.879},
#  {'text': 'Exactly. On the Galaxy S25', 'start': 184.48, 'duration': 5.119},
#  {'text': 'Ultra. Someone brought up an interesting',
#   'start': 188.159,
#   'duration': 2.72},
#  {'text': 'point. Are they going to call the new',
#   'start': 189.599,
#   'duration': 4.961},
#  {'text': "iPhone the iPhone 26 now? cuz it's going",
#   'start': 190.879,
#   'duration': 5.201},
#  {'text': 'to be a little awkward to have the',
#   'start': 194.56,
#   'duration': 4.319},
#  {'text': "iPhone 17 running iOS 26. They're going",
#   'start': 196.08,
#   'duration': 5.2},
#  {'text': 'to call it the iPhone 9. Oh god. Well,',
#   'start': 198.879,
#   'duration': 4.241},
#  {'text': "we Well, it didn't match before though.",
#   'start': 201.28,
#   'duration': 5.52},
#  {'text': "Yeah. True. Yeah. I don't think they're",
#   'start': 203.12,
#   'duration': 5.52},
#  {'text': "going to. I don't think they will. Okay.",
#   'start': 206.8,
#   'duration': 6.64},
#  {'text': "So, I iPhone 17 iOS 26. We'll see. We",
#   'start': 208.64,
#   'duration': 6.319},
#  {'text': "should place this bet. No, we'll see. Uh",
#   'start': 213.44,
#   'duration': 3.359},
#  {'text': "yeah, I guess we'll start. Speaking of a",
#   'start': 214.959,
#   'duration': 4.081},
#  {'text': 'bet. Yeah. What was our overunder last',
#   'start': 216.799,
#   'duration': 4.401},
#  {'text': 'week for how many times they say? I',
#   'start': 219.04,
#   'duration': 4.88},
#  {'text': 'think it was four 4.5 or something. and',
#   'start': 221.2,
#   'duration': 6.16},
#  {'text': 'I said under. It turns out they said the',
#   'start': 223.92,
#   'duration': 5.84},
#  {'text': 'word Siri', 'start': 227.36, 'duration': 6.239},
#  {'text': 'times total during the entire 90minute',
#   'start': 229.76,
#   'duration': 6.32},
#  {'text': 'presentation that main keynote. It was',
#   'start': 233.599,
#   'duration': 4.161},
#  {'text': 'right off the riff and they it was right',
#   'start': 236.08,
#   'duration': 2.96},
#  {'text': 'at the beginning and it was back to back',
#   'start': 237.76,
#   'duration': 2.72},
#  {'text': "and then they just didn't say the word",
#   'start': 239.04,
#   'duration': 3.6},
#  {'text': 'again. They they like weirdly went',
#   'start': 240.48,
#   'duration': 4.16},
#  {'text': "here's all the things Apple intelligence",
#   'start': 242.64,
#   'duration': 3.76},
#  {'text': 'brought and there was like this big list',
#   'start': 244.64,
#   'duration': 3.519},
#  {'text': 'that looked really impressive at first',
#   'start': 246.4,
#   'duration': 3.36},
#  {'text': 'but really it was a lot of very simple',
#   'start': 248.159,
#   'duration': 3.521},
#  {'text': 'things. And then I have the quote here.',
#   'start': 249.76,
#   'duration': 3.759},
#  {'text': "It's just we introduce enhancements",
#   'start': 251.68,
#   'duration': 3.68},
#  {'text': 'enhancements that makes Siri more',
#   'start': 253.519,
#   'duration': 3.84},
#  {'text': "natural, more helpful. And as we've",
#   'start': 255.36,
#   'duration': 3.439},
#  {'text': "shared, we're continuing our work to",
#   'start': 257.359,
#   'duration': 3.521},
#  {'text': 'deliver more features to Siri to make it',
#   'start': 258.799,
#   'duration': 4.081},
#  {'text': 'even more personal. This work needed',
#   'start': 260.88,
#   'duration': 4.0},
#  {'text': 'more time to reach our high quality bar.',
#   'start': 262.88,
#   'duration': 3.28},
#  {'text': 'And we look forward to sharing more in',
#   'start': 264.88,
#   'duration': 3.2},
#  {'text': 'the coming year. Yeah. So there was',
#   'start': 266.16,
#   'duration': 3.759},
#  {'text': 'there was an interview that was done',
#   'start': 268.08,
#   'duration': 4.96},
#  {'text': "with Craig Federiki by Tom's Guide that",
#   'start': 269.919,
#   'duration': 4.961},
#  {'text': "is very it's like 30 minutes long. It's",
#   'start': 273.04,
#   'duration': 3.439},
#  {'text': 'very good. You should go watch it. Uh',
#   'start': 274.88,
#   'duration': 3.039},
#  {'text': 'but he talks about it more in depth in',
#   'start': 276.479,
#   'duration': 3.121},
#  {'text': 'there. and he effectively said they had',
#   'start': 277.919,
#   'duration': 5.041},
#  {'text': 'two architectures for like the AI Siri',
#   'start': 279.6,
#   'duration': 7.12},
#  {'text': 'and architecture one was working but it',
#   'start': 282.96,
#   'duration': 6.48},
#  {'text': "wasn't like it the architecture wasn't",
#   'start': 286.72,
#   'duration': 4.88},
#  {'text': 'implemented across the whole system or',
#   'start': 289.44,
#   'duration': 4.16},
#  {'text': 'something like that and so it was',
#   'start': 291.6,
#   'duration': 3.92},
#  {'text': 'working and it was work for most things',
#   'start': 293.6,
#   'duration': 3.12},
#  {'text': "but it didn't meet their quality",
#   'start': 295.52,
#   'duration': 3.52},
#  {'text': 'standards and he said as soon as they',
#   'start': 296.72,
#   'duration': 3.759},
#  {'text': 'realized they needed to use the second',
#   'start': 299.04,
#   'duration': 2.719},
#  {'text': 'architecture they knew it was going to',
#   'start': 300.479,
#   'duration': 3.521},
#  {'text': 'take way longer and they immediately',
#   'start': 301.759,
#   'duration': 4.321},
#  {'text': "told everybody it's not ready. I heard a",
#   'start': 304.0,
#   'duration': 3.919},
#  {'text': 'similar answer from Craig talking to',
#   'start': 306.08,
#   'duration': 3.52},
#  {'text': 'Joanna Stern in a Wall Street Journal',
#   'start': 307.919,
#   'duration': 3.441},
#  {'text': 'video. Something about stage one was',
#   'start': 309.6,
#   'duration': 3.52},
#  {'text': 'good enough to demo, stage two took way',
#   'start': 311.36,
#   'duration': 4.08},
#  {'text': 'too long. Yeah, great. I mean, this is',
#   'start': 313.12,
#   'duration': 3.68},
#  {'text': 'basically all we got as far as them',
#   'start': 315.44,
#   'duration': 3.199},
#  {'text': 'addressing Siri in their main', 'start': 316.8, 'duration': 3.6},
#  {'text': 'presentation or at least the', 'start': 318.639, 'duration': 3.28},
#  {'text': 'shortcomings of Apple intelligence in',
#   'start': 320.4,
#   'duration': 2.799},
#  {'text': 'the main presentation. And then they',
#   'start': 321.919,
#   'duration': 3.761},
#  {'text': 'quickly moved on to just showing a ton',
#   'start': 323.199,
#   'duration': 6.321},
#  {'text': 'of other stuff, which in my opinion was',
#   'start': 325.68,
#   'duration': 5.2},
#  {'text': 'it was a lot. It was quite a bit. I',
#   'start': 329.52,
#   'duration': 3.679},
#  {'text': 'think it was enough to have some',
#   'start': 330.88,
#   'duration': 4.48},
#  {'text': 'thoughts and some meat to chew on while',
#   'start': 333.199,
#   'duration': 3.521},
#  {'text': 'we also wait for the rest of Apple',
#   'start': 335.36,
#   'duration': 3.2},
#  {'text': 'intelligence stuff and more AI features.',
#   'start': 336.72,
#   'duration': 3.12},
#  {'text': 'I think the way that they addressed it',
#   'start': 338.56,
#   'duration': 2.56},
#  {'text': 'was actually very smart because they',
#   'start': 339.84,
#   'duration': 4.639},
#  {'text': 'kind of took the like bad is forever and',
#   'start': 341.12,
#   'duration': 6.0},
#  {'text': 'delay is temporary approach. Just saying',
#   'start': 344.479,
#   'duration': 4.56},
#  {'text': 'like we want this to be good. We have',
#   'start': 347.12,
#   'duration': 4.16},
#  {'text': 'quality standards. Just wait for it. I',
#   'start': 349.039,
#   'duration': 3.44},
#  {'text': "think that's always the best way to",
#   'start': 351.28,
#   'duration': 3.52},
#  {'text': 'delay things honestly. Sure. Uh how it',
#   'start': 352.479,
#   'duration': 3.44},
#  {'text': 'affects their stock price, I have no',
#   'start': 354.8,
#   'duration': 3.119},
#  {'text': "idea. It didn't do very well, I don't",
#   'start': 355.919,
#   'duration': 3.761},
#  {'text': 'think, when it got announced. You know,',
#   'start': 357.919,
#   'duration': 3.761},
#  {'text': "that's how it is. Anyway, well, we could",
#   'start': 359.68,
#   'duration': 3.92},
#  {'text': 'talk about any number of these 26',
#   'start': 361.68,
#   'duration': 3.92},
#  {'text': 'versions of OS first, but I think the',
#   'start': 363.6,
#   'duration': 3.52},
#  {'text': 'one that most people want to talk about',
#   'start': 365.6,
#   'duration': 3.92},
#  {'text': 'is iOS 26. So, we should probably just',
#   'start': 367.12,
#   'duration': 6.16},
#  {'text': 'jump in there. So, liquid new Yeah,',
#   'start': 369.52,
#   'duration': 7.519},
#  {'text': 'liquid liquid glass everywhere. Liquid',
#   'start': 373.28,
#   'duration': 7.6},
#  {'text': 'glass is uh the new aesthetic that is',
#   'start': 377.039,
#   'duration': 5.44},
#  {'text': 'specifically', 'start': 380.88, 'duration': 5.12},
#  {'text': 'the transparent and refractive almost',
#   'start': 382.479,
#   'duration': 6.801},
#  {'text': 'material design of all of these buttons',
#   'start': 386.0,
#   'duration': 5.28},
#  {'text': 'and toggles and materials, the lock',
#   'start': 389.28,
#   'duration': 3.759},
#  {'text': 'screen, the clock, the fonts, the',
#   'start': 391.28,
#   'duration': 5.039},
#  {'text': "windows, the everything. Yeah. And it's",
#   'start': 393.039,
#   'duration': 5.121},
#  {'text': "taking after a lot of what we've seen in",
#   'start': 396.319,
#   'duration': 7.6},
#  {'text': "Vision Pro. So I am mixed on it. I've",
#   'start': 398.16,
#   'duration': 8.56},
#  {'text': 'seen screenshots of it that look really',
#   'start': 403.919,
#   'duration': 5.28},
#  {'text': "good. Yeah, I've seen screenshots of it",
#   'start': 406.72,
#   'duration': 5.12},
#  {'text': 'that look really bad. Yeah, I think the',
#   'start': 409.199,
#   'duration': 5.521},
#  {'text': 'the parts that look really good to me',
#   'start': 411.84,
#   'duration': 5.76},
#  {'text': 'are like extra clean and look pretty',
#   'start': 414.72,
#   'duration': 4.96},
#  {'text': "minimal and they're like buttons hiding",
#   'start': 417.6,
#   'duration': 4.24},
#  {'text': 'out of the way and nice animations and',
#   'start': 419.68,
#   'duration': 3.68},
#  {'text': 'things pop in and out and the physics',
#   'start': 421.84,
#   'duration': 3.199},
#  {'text': "are nice and I'm sure the haptics match.",
#   'start': 423.36,
#   'duration': 5.04},
#  {'text': 'Yeah. The parts that look really bad are',
#   'start': 425.039,
#   'duration': 5.761},
#  {'text': "Okay, so there's this thing and I talked",
#   'start': 428.4,
#   'duration': 4.079},
#  {'text': "about this briefly in videos. It's not",
#   'start': 430.8,
#   'duration': 3.119},
#  {'text': "super complicated. When you're editing a",
#   'start': 432.479,
#   'duration': 3.12},
#  {'text': "video and you're putting text in it, you",
#   'start': 433.919,
#   'duration': 3.361},
#  {'text': 'try to find like a clean place in the',
#   'start': 435.599,
#   'duration': 3.6},
#  {'text': 'video to put the text, right? And if you',
#   'start': 437.28,
#   'duration': 3.199},
#  {'text': "don't have any clean place to put the",
#   'start': 439.199,
#   'duration': 3.601},
#  {'text': 'video, you can put a little background,',
#   'start': 440.479,
#   'duration': 4.72},
#  {'text': 'like a little soft white or soft black,',
#   'start': 442.8,
#   'duration': 4.08},
#  {'text': 'so that you can put the text on it and',
#   'start': 445.199,
#   'duration': 4.321},
#  {'text': "it's contrasty and it's readable.",
#   'start': 446.88,
#   'duration': 5.12},
#  {'text': "If you don't, you can't read the text",
#   'start': 449.52,
#   'duration': 4.72},
#  {'text': 'very well. And so with all this', 'start': 452.0, 'duration': 4.72},
#  {'text': 'transparency, there are many instances',
#   'start': 454.24,
#   'duration': 5.76},
#  {'text': 'that I saw where Apple is trying to do',
#   'start': 456.72,
#   'duration': 5.28},
#  {'text': 'this really clever like dynamic',
#   'start': 460.0,
#   'duration': 4.639},
#  {'text': 'switching of light on dark background',
#   'start': 462.0,
#   'duration': 4.72},
#  {'text': "and dark on light background. So you'll",
#   'start': 464.639,
#   'duration': 4.881},
#  {'text': 'scroll past a dark album cover. Yeah.',
#   'start': 466.72,
#   'duration': 4.879},
#  {'text': 'And all the UI elements that you have',
#   'start': 469.52,
#   'duration': 4.16},
#  {'text': 'like floating in this glass above it',
#   'start': 471.599,
#   'duration': 3.921},
#  {'text': 'turn light so that they stay readable.',
#   'start': 473.68,
#   'duration': 3.6},
#  {'text': 'Yeah. And then you go past it to some',
#   'start': 475.52,
#   'duration': 3.84},
#  {'text': 'white empty space and all that stuff',
#   'start': 477.28,
#   'duration': 4.72},
#  {'text': 'flips to dark so that it stays readable.',
#   'start': 479.36,
#   'duration': 4.16},
#  {'text': 'And they try to do this really quickly',
#   'start': 482.0,
#   'duration': 3.12},
#  {'text': "and smoothly so that you don't really",
#   'start': 483.52,
#   'duration': 3.76},
#  {'text': "notice, but it's always readable. But",
#   'start': 485.12,
#   'duration': 4.16},
#  {'text': 'there are so many instances of like',
#   'start': 487.28,
#   'duration': 4.08},
#  {'text': 'scrolling or being halfway between a',
#   'start': 489.28,
#   'duration': 5.84},
#  {'text': 'dark and a light where things just look',
#   'start': 491.36,
#   'duration': 5.6},
#  {'text': "weird and hard to read. Yeah, it's",
#   'start': 495.12,
#   'duration': 4.079},
#  {'text': 'definitely relying a lot on the system',
#   'start': 496.96,
#   'duration': 4.959},
#  {'text': "to acknowledge what's on the screen.",
#   'start': 499.199,
#   'duration': 4.4},
#  {'text': "Yeah, obviously I'm on the first",
#   'start': 501.919,
#   'duration': 3.68},
#  {'text': "developer beta and it's not bugging",
#   'start': 503.599,
#   'duration': 3.361},
#  {'text': 'right now. Probably because I have this',
#   'start': 505.599,
#   'duration': 3.28},
#  {'text': 'like dark widget near the top. when that',
#   'start': 506.96,
#   'duration': 4.16},
#  {'text': 'dark widget is not there, most of the',
#   'start': 508.879,
#   'duration': 4.72},
#  {'text': "time the text just it's almost",
#   'start': 511.12,
#   'duration': 4.479},
#  {'text': 'unreadable. It actually darkens the',
#   'start': 513.599,
#   'duration': 4.8},
#  {'text': 'background to allow it to be a little',
#   'start': 515.599,
#   'duration': 4.641},
#  {'text': 'more readable. I think one of the',
#   'start': 518.399,
#   'duration': 4.08},
#  {'text': 'primary problems right now that they may',
#   'start': 520.24,
#   'duration': 3.919},
#  {'text': 'change once they do more developer betas',
#   'start': 522.479,
#   'duration': 5.92},
#  {'text': 'is that the text is white on top of a',
#   'start': 524.159,
#   'duration': 7.12},
#  {'text': 'mostly white translucent background on',
#   'start': 528.399,
#   'duration': 5.44},
#  {'text': 'top of a light background. So, it',
#   'start': 531.279,
#   'duration': 4.24},
#  {'text': 'darkens the background automatically,',
#   'start': 533.839,
#   'duration': 3.68},
#  {'text': "but it doesn't always do that. And",
#   'start': 535.519,
#   'duration': 3.76},
#  {'text': "honestly, it's been not doing that most",
#   'start': 537.519,
#   'duration': 3.921},
#  {'text': 'of the time. Um, and I again, I only',
#   'start': 539.279,
#   'duration': 3.841},
#  {'text': "think it's doing that because I have a a",
#   'start': 541.44,
#   'duration': 3.92},
#  {'text': "black widget that's counting down right",
#   'start': 543.12,
#   'duration': 4.56},
#  {'text': 'now. I think Yeah, our designers were',
#   'start': 545.36,
#   'duration': 4.0},
#  {'text': 'very surprised when they first saw that.',
#   'start': 547.68,
#   'duration': 3.599},
#  {'text': 'They\'re like, "That does not meet the',
#   'start': 549.36,
#   'duration': 4.08},
#  {'text': 'like contrast standards or whatever that',
#   'start': 551.279,
#   'duration': 5.281},
#  {'text': 'they, you know, went to school for."',
#   'start': 553.44,
#   'duration': 5.28},
#  {'text': "It's bold. It's bold. It It strikes me",
#   'start': 556.56,
#   'duration': 4.32},
#  {'text': 'as a design that a lot of people are not',
#   'start': 558.72,
#   'duration': 4.559},
#  {'text': 'going to copy. Some definitely will.',
#   'start': 560.88,
#   'duration': 5.04},
#  {'text': 'They always do. But like Apple showed uh',
#   'start': 563.279,
#   'duration': 5.601},
#  {'text': 'an allcle all glass home screen setup',
#   'start': 565.92,
#   'duration': 4.64},
#  {'text': 'where you have whatever wallpaper you',
#   'start': 568.88,
#   'duration': 3.04},
#  {'text': 'want and then all of your icons are',
#   'start': 570.56,
#   'duration': 2.8},
#  {'text': 'clear, all your widgets are clear,',
#   'start': 571.92,
#   'duration': 5.28},
#  {'text': "everything is clear. That doesn't feel",
#   'start': 573.36,
#   'duration': 5.68},
#  {'text': 'that feels like a skin like I installed',
#   'start': 577.2,
#   'duration': 3.36},
#  {'text': 'on top of my phone. Everyone was',
#   'start': 579.04,
#   'duration': 3.28},
#  {'text': 'comparing it to like old Android skins',
#   'start': 580.56,
#   'duration': 4.08},
#  {'text': "from like 10 years ago. Yes, it's it",
#   'start': 582.32,
#   'duration': 4.0},
#  {'text': "it's the look of the year. I don't know",
#   'start': 584.64,
#   'duration': 3.68},
#  {'text': 'if this is going to age very well. I',
#   'start': 586.32,
#   'duration': 4.72},
#  {'text': "don't want an allcle setup. I mean, it's",
#   'start': 588.32,
#   'duration': 3.92},
#  {'text': 'cool if you love your wallpaper, but',
#   'start': 591.04,
#   'duration': 2.88},
#  {'text': 'like I need to be able to read the icons',
#   'start': 592.24,
#   'duration': 3.92},
#  {'text': 'and the text. So, yeah. Yeah, that',
#   'start': 593.92,
#   'duration': 4.88},
#  {'text': "didn't look great to me. Liquid glass in",
#   'start': 596.16,
#   'duration': 4.16},
#  {'text': 'general, I think, is like very', 'start': 598.8, 'duration': 4.88},
#  {'text': 'technically beautiful and impressive and',
#   'start': 600.32,
#   'duration': 4.88},
#  {'text': 'you can see like the light bending',
#   'start': 603.68,
#   'duration': 3.12},
#  {'text': 'around certain elements and things like',
#   'start': 605.2,
#   'duration': 4.24},
#  {'text': "that and like light refracting and it's",
#   'start': 606.8,
#   'duration': 4.8},
#  {'text': 'awesome to like look at, but practically',
#   'start': 609.44,
#   'duration': 4.24},
#  {'text': "on a phone it's like so distracting like",
#   'start': 611.6,
#   'duration': 4.479},
#  {'text': "it's so much. I thought for a lot of the",
#   'start': 613.68,
#   'duration': 4.0},
#  {'text': 'things', 'start': 616.079, 'duration': 3.281},
#  {'text': 'it besides the like transparent on',
#   'start': 617.68,
#   'duration': 3.52},
#  {'text': 'transparent one looked good. Like the',
#   'start': 619.36,
#   'duration': 3.919},
#  {'text': 'dark mode icons that still had that like',
#   'start': 621.2,
#   'duration': 4.079},
#  {'text': 'sheen to it and a little bit of like',
#   'start': 623.279,
#   'duration': 3.921},
#  {'text': 'depth. I thought those looked like I',
#   'start': 625.279,
#   'duration': 5.12},
#  {'text': 'think there was a dark mode photos uh',
#   'start': 627.2,
#   'duration': 5.92},
#  {'text': 'like icon that looked really really',
#   'start': 630.399,
#   'duration': 4.721},
#  {'text': 'good. Yeah. Um, and like just looking at',
#   'start': 633.12,
#   'duration': 3.36},
#  {'text': "David's phone right now, he's going",
#   'start': 635.12,
#   'duration': 3.6},
#  {'text': 'through it. When you had the um just',
#   'start': 636.48,
#   'duration': 4.64},
#  {'text': 'your lock screen up, like the background',
#   'start': 638.72,
#   'duration': 5.2},
#  {'text': 'pieces looking once it like opens up and',
#   'start': 641.12,
#   'duration': 4.959},
#  {'text': 'it it kind of has this like sheen to the',
#   'start': 643.92,
#   'duration': 3.68},
#  {'text': 'edges of all the background pieces and',
#   'start': 646.079,
#   'duration': 4.241},
#  {'text': 'the the time fits really nicely in that',
#   'start': 647.6,
#   'duration': 5.679},
#  {'text': 'looks really good. Yeah. But then the',
#   'start': 650.32,
#   'duration': 4.32},
#  {'text': 'transparent on transparent is the one',
#   'start': 653.279,
#   'duration': 2.56},
#  {'text': "we're all looking at cuz it's the most",
#   'start': 654.64,
#   'duration': 2.8},
#  {'text': 'obvious. I think that looks terrible.',
#   'start': 655.839,
#   'duration': 3.361},
#  {'text': 'Yeah. Yeah. There are new icon designs',
#   'start': 657.44,
#   'duration': 4.48},
#  {'text': "across the board. There's a new I mean,",
#   'start': 659.2,
#   'duration': 4.4},
#  {'text': "we'll get to other oss in a second, but",
#   'start': 661.92,
#   'duration': 3.44},
#  {'text': "there's there's a new camera icon.",
#   'start': 663.6,
#   'duration': 4.72},
#  {'text': "There's a new phone icon, new slightly",
#   'start': 665.36,
#   'duration': 5.68},
#  {'text': 'different looking icons that all still',
#   'start': 668.32,
#   'duration': 4.32},
#  {'text': 'look familiar, but are just a little bit',
#   'start': 671.04,
#   'duration': 4.56},
#  {'text': 'different. Yeah. Uh yeah, I will say it',
#   'start': 672.64,
#   'duration': 8.08},
#  {'text': "looks a lot like iOS 7, which I'm kind",
#   'start': 675.6,
#   'duration': 8.239},
#  {'text': 'of digging in a strange way. I can kind',
#   'start': 680.72,
#   'duration': 6.4},
#  {'text': 'of acknowledge that the design is not',
#   'start': 683.839,
#   'duration': 5.44},
#  {'text': 'Can I see that roof? Fantastic or like',
#   'start': 687.12,
#   'duration': 4.64},
#  {'text': "it's not really what people expect for",
#   'start': 689.279,
#   'duration': 5.841},
#  {'text': 'right now in design history.', 'start': 691.76, 'duration': 6.72},
#  {'text': "But I do like that it's opinionated",
#   'start': 695.12,
#   'duration': 5.12},
#  {'text': 'because now we have material 3', 'start': 698.48, 'duration': 3.44},
#  {'text': 'expressive which is very opinionated and',
#   'start': 700.24,
#   'duration': 3.599},
#  {'text': 'we have this which is very opinionated.',
#   'start': 701.92,
#   'duration': 4.479},
#  {'text': 'The surprise that I had not opinionated',
#   'start': 703.839,
#   'duration': 8.0},
#  {'text': 'rebellious remember. Right. Uh yeah I I',
#   'start': 706.399,
#   'duration': 6.801},
#  {'text': "lost my train of thought. I'm sorry,",
#   'start': 711.839,
#   'duration': 4.161},
#  {'text': "dude. No, it's okay. It's okay. Um Oh,",
#   'start': 713.2,
#   'duration': 5.68},
#  {'text': 'it is more cartoony than I expected.',
#   'start': 716.0,
#   'duration': 5.04},
#  {'text': 'Bubbles. A lot of bubbles. Just like the',
#   'start': 718.88,
#   'duration': 4.56},
#  {'text': 'the icons and shapes. Spongebob shapes.',
#   'start': 721.04,
#   'duration': 4.56},
#  {'text': 'They they look really big on your They',
#   'start': 723.44,
#   'duration': 5.36},
#  {'text': 'are big. Okay. That in itself.', 'start': 725.6, 'duration': 4.64},
#  {'text': "Okay, that's an option. I need you guys",
#   'start': 728.8,
#   'duration': 4.32},
#  {'text': 'to Google Spongebob Bubble Buddy.',
#   'start': 730.24,
#   'duration': 6.76},
#  {'text': "We don't We don't have to", 'start': 733.12, 'duration': 3.88},
#  {'text': "picture it. Yeah, that's that's the new",
#   'start': 737.2,
#   'duration': 4.16},
#  {'text': 'control pretty much. Yeah. Was it Ellis',
#   'start': 739.519,
#   'duration': 2.88},
#  {'text': 'who said this should have been called',
#   'start': 741.36,
#   'duration': 3.44},
#  {'text': 'stained glass? I think you said that.',
#   'start': 742.399,
#   'duration': 4.24},
#  {'text': "No, that's what Well, you could have",
#   'start': 744.8,
#   'duration': 3.2},
#  {'text': 'taken credit for it because it makes way',
#   'start': 746.639,
#   'duration': 3.76},
#  {'text': "more sense. Like I don't know. Photos",
#   'start': 748.0,
#   'duration': 3.6},
#  {'text': 'app looks great. I actually think that',
#   'start': 750.399,
#   'duration': 5.041},
#  {'text': 'Spotify app looks really good. Um but I',
#   'start': 751.6,
#   'duration': 6.08},
#  {'text': 'mean my favorite part about this is',
#   'start': 755.44,
#   'duration': 4.639},
#  {'text': 'every time any company tries to make all',
#   'start': 757.68,
#   'duration': 4.24},
#  {'text': 'icons on a homepage look the same,',
#   'start': 760.079,
#   'duration': 4.56},
#  {'text': "there's always a couple apps that just",
#   'start': 761.92,
#   'duration': 4.479},
#  {'text': "don't match it. And I've seen a bunch of",
#   'start': 764.639,
#   'duration': 3.681},
#  {'text': 'people post stuff already like the chat',
#   'start': 766.399,
#   'duration': 4.961},
#  {'text': 'GBT app is just still a plain white app.',
#   'start': 768.32,
#   'duration': 6.16},
#  {'text': "And the minute one icon doesn't match",
#   'start': 771.36,
#   'duration': 5.279},
#  {'text': 'all the other ones, none of them match.',
#   'start': 774.48,
#   'duration': 4.64},
#  {'text': 'Yeah, it happens every time. They also',
#   'start': 776.639,
#   'duration': 4.241},
#  {'text': 'So I think it was last year that they',
#   'start': 779.12,
#   'duration': 3.92},
#  {'text': 'introduced the tinted icons or was that',
#   'start': 780.88,
#   'duration': 3.36},
#  {'text': 'two years ago? I think it might have',
#   'start': 783.04,
#   'duration': 2.4},
#  {'text': 'been two years. It was two years ago.',
#   'start': 784.24,
#   'duration': 4.64},
#  {'text': "And they those I I still I think that's",
#   'start': 785.44,
#   'duration': 5.92},
#  {'text': 'even more of a case of like in like one',
#   'start': 788.88,
#   'duration': 4.079},
#  {'text': 'or two instances you can make it look',
#   'start': 791.36,
#   'duration': 3.76},
#  {'text': 'decent, but otherwise it looks terrible.',
#   'start': 792.959,
#   'duration': 4.721},
#  {'text': 'Uh, they also introduced this new clear',
#   'start': 795.12,
#   'duration': 4.719},
#  {'text': 'one that they decided to highlight a lot',
#   'start': 797.68,
#   'duration': 6.159},
#  {'text': "for some reason. Yeah. I just It's hard",
#   'start': 799.839,
#   'duration': 6.081},
#  {'text': 'to distinguish anything. I do not know',
#   'start': 803.839,
#   'duration': 3.521},
#  {'text': 'what they were thinking with that. No.',
#   'start': 805.92,
#   'duration': 2.56},
#  {'text': "Yeah. I think that's the one we were",
#   'start': 807.36,
#   'duration': 3.279},
#  {'text': 'saying like that one makes the least',
#   'start': 808.48,
#   'duration': 3.76},
#  {'text': "sense out of all of it. It's the most",
#   'start': 810.639,
#   'duration': 3.361},
#  {'text': "eye-catching. It's the reason everyone",
#   'start': 812.24,
#   'duration': 2.719},
#  {'text': "used it in their thumbnail. It's going",
#   'start': 814.0,
#   'duration': 2.8},
#  {'text': 'to age the fastest. It looks bad though.',
#   'start': 814.959,
#   'duration': 3.201},
#  {'text': "Like you can't like in all the", 'start': 816.8, 'duration': 2.56},
#  {'text': "thumbnails I'm like I don't know what",
#   'start': 818.16,
#   'duration': 2.56},
#  {'text': "app that is. I don't know what app that",
#   'start': 819.36,
#   'duration': 3.279},
#  {'text': "is. Yeah. You know, I It's just", 'start': 820.72, 'duration': 4.4},
#  {'text': 'confusing. May this is also maybe and we',
#   'start': 822.639,
#   'duration': 3.921},
#  {'text': 'can move on from it in a second but this',
#   'start': 825.12,
#   'duration': 3.2},
#  {'text': 'may also be a thing where when app',
#   'start': 826.56,
#   'duration': 4.16},
#  {'text': 'developers who have third party apps',
#   'start': 828.32,
#   'duration': 4.16},
#  {'text': 'they update their app icons maybe',
#   'start': 830.72,
#   'duration': 3.04},
#  {'text': "they'll be a little bit more legible",
#   'start': 832.48,
#   'duration': 3.919},
#  {'text': "because as of right now Apple's own apps",
#   'start': 833.76,
#   'duration': 4.8},
#  {'text': "they've designed for this and if they're",
#   'start': 836.399,
#   'duration': 4.081},
#  {'text': 'not designed for this then they can be',
#   'start': 838.56,
#   'duration': 3.36},
#  {'text': 'automatically converted but maybe they',
#   'start': 840.48,
#   'duration': 3.28},
#  {'text': "aren't as contrasty as they could be",
#   'start': 841.92,
#   'duration': 4.0},
#  {'text': "right so we can give it time it's a",
#   'start': 843.76,
#   'duration': 4.079},
#  {'text': "public beta or it's a developer beta now",
#   'start': 845.92,
#   'duration': 3.599},
#  {'text': "it's very early", 'start': 847.839, 'duration': 4.24},
#  {'text': "we'll see I also want to say that like",
#   'start': 849.519,
#   'duration': 4.961},
#  {'text': 'using their stock wallpapers. All this',
#   'start': 852.079,
#   'duration': 4.081},
#  {'text': 'stuff looks good, but like using your',
#   'start': 854.48,
#   'duration': 3.52},
#  {'text': 'own wallpapers, it looks much worse.',
#   'start': 856.16,
#   'duration': 3.2},
#  {'text': "Exactly. That's what I'm thinking. It's",
#   'start': 858.0,
#   'duration': 3.04},
#  {'text': 'It looks much worse. Legibility is going',
#   'start': 859.36,
#   'duration': 3.039},
#  {'text': 'to be challenging. I think that they',
#   'start': 861.04,
#   'duration': 2.88},
#  {'text': 'designed some wallpapers that are just',
#   'start': 862.399,
#   'duration': 3.44},
#  {'text': 'like a couple of colors that are also',
#   'start': 863.92,
#   'duration': 3.76},
#  {'text': 'glassy and everything kind of works well',
#   'start': 865.839,
#   'duration': 3.521},
#  {'text': "together and they're dynamic so that it",
#   'start': 867.68,
#   'duration': 3.12},
#  {'text': 'gets darker in certain times, but when',
#   'start': 869.36,
#   'duration': 3.12},
#  {'text': "you use your own wallpapers, it's like",
#   'start': 870.8,
#   'duration': 3.2},
#  {'text': "it's like when remember when they first",
#   'start': 872.48,
#   'duration': 3.44},
#  {'text': 'introduced the notch, all their', 'start': 874.0, 'duration': 3.68},
#  {'text': 'wallpapers were very dark on the top so',
#   'start': 875.92,
#   'duration': 2.88},
#  {'text': "you like you couldn't see it. They know",
#   'start': 877.68,
#   'duration': 2.8},
#  {'text': "what they're doing for sure. They know",
#   'start': 878.8,
#   'duration': 3.68},
#  {'text': "the things that aren't quite perfect and",
#   'start': 880.48,
#   'duration': 4.0},
#  {'text': 'how to make them look fantastic and then',
#   'start': 882.48,
#   'duration': 3.359},
#  {'text': 'you put a picture of your kid up and it',
#   'start': 884.48,
#   'duration': 6.08},
#  {'text': 'looks terrible. Yeah, I Ellis also',
#   'start': 885.839,
#   'duration': 7.721},
#  {'text': 'watched', 'start': 890.56, 'duration': 3.0},
#  {'text': 'I was watching Dubdub like the rest of',
#   'start': 894.079,
#   'duration': 3.361},
#  {'text': 'us and was sort of like unimpressed by',
#   'start': 896.0,
#   'duration': 5.68},
#  {'text': 'the liquid glass thing. But on Twitter,',
#   'start': 897.44,
#   'duration': 6.079},
#  {'text': 'uh, this guy who works for Apple as an',
#   'start': 901.68,
#   'duration': 3.36},
#  {'text': 'interface designer named Sean', 'start': 903.519, 'duration': 3.68},
#  {'text': 'Coronamoney, uh, who worked on Liquid',
#   'start': 905.04,
#   'duration': 4.799},
#  {'text': 'Glass posted this quick like 45 second',
#   'start': 907.199,
#   'duration': 4.561},
#  {'text': 'video of just sort of demonstrating some',
#   'start': 909.839,
#   'duration': 4.961},
#  {'text': 'of the things it can do. Um, which I',
#   'start': 911.76,
#   'duration': 4.639},
#  {'text': 'left in the show notes if you want to',
#   'start': 914.8,
#   'duration': 4.24},
#  {'text': 'watch it yourself. Um, and it actually',
#   'start': 916.399,
#   'duration': 5.041},
#  {'text': 'like completely changed how I felt about',
#   'start': 919.04,
#   'duration': 5.52},
#  {'text': 'liquid glass because I sort of saw it in',
#   'start': 921.44,
#   'duration': 6.079},
#  {'text': 'the same way I saw Windows Arrow or Mac',
#   'start': 924.56,
#   'duration': 4.959},
#  {'text': 'or like Aqua as like this overarching',
#   'start': 927.519,
#   'duration': 5.281},
#  {'text': "design language, but I think it's",
#   'start': 929.519,
#   'duration': 5.601},
#  {'text': 'actually much more of a lighting engine',
#   'start': 932.8,
#   'duration': 3.839},
#  {'text': 'because when you look at this sort of he',
#   'start': 935.12,
#   'duration': 3.2},
#  {'text': "it's all these close-ups of the buttons",
#   'start': 936.639,
#   'duration': 3.841},
#  {'text': 'and stuff and really what it enables you',
#   'start': 938.32,
#   'duration': 4.72},
#  {'text': 'to do in your interfaces is have',
#   'start': 940.48,
#   'duration': 4.799},
#  {'text': "threepoint lighting because there's",
#   'start': 943.04,
#   'duration': 3.919},
#  {'text': 'specular highlights on all the ri like',
#   'start': 945.279,
#   'duration': 5.12},
#  {'text': 'you get real rim lighting effects. And I',
#   'start': 946.959,
#   'duration': 5.44},
#  {'text': 'feel like what this actually brings to',
#   'start': 950.399,
#   'duration': 4.0},
#  {'text': "the table, you know, I'm not like an",
#   'start': 952.399,
#   'duration': 4.481},
#  {'text': 'expert 3D renderer guy. I just sort of',
#   'start': 954.399,
#   'duration': 4.481},
#  {'text': 'fool around with it. But things like rim',
#   'start': 956.88,
#   'duration': 5.12},
#  {'text': 'lighting can be really intensive like',
#   'start': 958.88,
#   'duration': 5.519},
#  {'text': 'computewise. And so if Apple figured out',
#   'start': 962.0,
#   'duration': 4.079},
#  {'text': 'a way to like optimize a lot of these',
#   'start': 964.399,
#   'duration': 3.761},
#  {'text': 'effects like diffusion, specular',
#   'start': 966.079,
#   'duration': 4.481},
#  {'text': 'highlights, things like that, and then',
#   'start': 968.16,
#   'duration': 4.72},
#  {'text': 'package it in a way that developers can',
#   'start': 970.56,
#   'duration': 4.88},
#  {'text': 'implement it really easily. Allah, you',
#   'start': 972.88,
#   'duration': 4.48},
#  {'text': 'know, our vision pro episode and talking',
#   'start': 975.44,
#   'duration': 3.839},
#  {'text': 'about all these sort of APIs that they',
#   'start': 977.36,
#   'duration': 3.839},
#  {'text': "give developers. Uh, I don't believe",
#   'start': 979.279,
#   'duration': 3.441},
#  {'text': 'they discussed APIs in like the',
#   'start': 981.199,
#   'duration': 4.0},
#  {'text': '20-minute liquid glass specific talk.',
#   'start': 982.72,
#   'duration': 5.6},
#  {'text': 'Um, but I would be curious in about 6 to',
#   'start': 985.199,
#   'duration': 4.801},
#  {'text': '12 months interviewing a bunch of',
#   'start': 988.32,
#   'duration': 5.439},
#  {'text': 'developers and learning about how a how',
#   'start': 990.0,
#   'duration': 5.839},
#  {'text': 'hardware intensive these lighting',
#   'start': 993.759,
#   'duration': 4.161},
#  {'text': 'effects are and then b how as a',
#   'start': 995.839,
#   'duration': 4.56},
#  {'text': "developer you're given the support to",
#   'start': 997.92,
#   'duration': 4.96},
#  {'text': "make your stuff this. I don't know.",
#   'start': 1000.399,
#   'duration': 4.161},
#  {'text': 'Watching this 45 second thing really',
#   'start': 1002.88,
#   'duration': 3.36},
#  {'text': 'changed my opinion on it to be like',
#   'start': 1004.56,
#   'duration': 3.6},
#  {'text': 'actually these are some potentially',
#   'start': 1006.24,
#   'duration': 4.399},
#  {'text': 'really powerful visual effects that',
#   'start': 1008.16,
#   'duration': 4.72},
#  {'text': 'might be packaged in a way that enables',
#   'start': 1010.639,
#   'duration': 4.481},
#  {'text': 'them to really be everywhere. RTX on.',
#   'start': 1012.88,
#   'duration': 5.199},
#  {'text': "Now, I I agree that the more I've",
#   'start': 1015.12,
#   'duration': 5.04},
#  {'text': 'watched from Apple itself, the more',
#   'start': 1018.079,
#   'duration': 6.321},
#  {'text': 'impressed I am with how powerful and how',
#   'start': 1020.16,
#   'duration': 7.519},
#  {'text': 'intricate a lot of these effects are. If',
#   'start': 1024.4,
#   'duration': 5.279},
#  {'text': "you've seen people do the like cursor",
#   'start': 1027.679,
#   'duration': 3.681},
#  {'text': 'hovering effect, instead of just being a',
#   'start': 1029.679,
#   'duration': 4.081},
#  {'text': 'bubble, it has like clear shape to the',
#   'start': 1031.36,
#   'duration': 4.079},
#  {'text': 'edges of the bubble. So, the the light',
#   'start': 1033.76,
#   'duration': 3.679},
#  {'text': 'sort of refracts differently around the',
#   'start': 1035.439,
#   'duration': 3.841},
#  {'text': 'edges versus the center. All these',
#   'start': 1037.439,
#   'duration': 3.6},
#  {'text': 'little things. or like on sliders where',
#   'start': 1039.28,
#   'duration': 4.0},
#  {'text': 'the rim, excuse me, on sliders when the',
#   'start': 1041.039,
#   'duration': 4.241},
#  {'text': 'rim lighting like changes depending on',
#   'start': 1043.28,
#   'duration': 4.639},
#  {'text': 'where you are in the which by the way uh',
#   'start': 1045.28,
#   'duration': 4.8},
#  {'text': 'for the Mac with the touch bar they',
#   'start': 1047.919,
#   'duration': 4.481},
#  {'text': 'actually updated the touch bar to have',
#   'start': 1050.08,
#   'duration': 4.88},
#  {'text': "liquid touch bar. That's funny. On the",
#   'start': 1052.4,
#   'duration': 5.84},
#  {'text': 'well the one that the old one they touch',
#   'start': 1054.96,
#   'duration': 5.12},
#  {'text': 'bar to be a liquid glass touch bar.',
#   'start': 1058.24,
#   'duration': 4.24},
#  {'text': "That's so funny. Interesting. know, I I",
#   'start': 1060.08,
#   'duration': 5.04},
#  {'text': 'see all of that and I on one hand I I',
#   'start': 1062.48,
#   'duration': 5.28},
#  {'text': 'can be both impressed by how intricate',
#   'start': 1065.12,
#   'duration': 5.439},
#  {'text': 'and how powerful these effects are in',
#   'start': 1067.76,
#   'duration': 6.08},
#  {'text': 'real time and also', 'start': 1070.559, 'duration': 5.12},
#  {'text': 'think about, you know, your scientists',
#   'start': 1073.84,
#   'duration': 3.6},
#  {'text': 'were so preoccupied with whether or not',
#   'start': 1075.679,
#   'duration': 3.521},
#  {'text': "they could that they didn't think about",
#   'start': 1077.44,
#   'duration': 3.52},
#  {'text': 'whether or not they should. Some people',
#   'start': 1079.2,
#   'duration': 4.4},
#  {'text': 'are going to make some really sick like',
#   'start': 1080.96,
#   'duration': 4.24},
#  {'text': 'themes and stuff on there and like with',
#   'start': 1083.6,
#   'duration': 3.36},
#  {'text': 'a great wallpaper that all matches and',
#   'start': 1085.2,
#   'duration': 3.2},
#  {'text': 'their home screens are going to look',
#   'start': 1086.96,
#   'duration': 4.079},
#  {'text': 'incredible. And then some of our parents',
#   'start': 1088.4,
#   'duration': 3.92},
#  {'text': 'are going to turn on the fully',
#   'start': 1091.039,
#   'duration': 4.241},
#  {'text': 'transparent one and try and call us to',
#   'start': 1092.32,
#   'duration': 4.64},
#  {'text': 'be like, "Why can I not read?" And the',
#   'start': 1095.28,
#   'duration': 3.04},
#  {'text': 'icons are see-through. What the hell is',
#   'start': 1096.96,
#   'duration': 2.719},
#  {'text': "this? Yeah. It's one of those questions",
#   'start': 1098.32,
#   'duration': 4.479},
#  {'text': "that it's like if nobody if the average",
#   'start': 1099.679,
#   'duration': 6.161},
#  {'text': "user can't make it look good, is it good",
#   'start': 1102.799,
#   'duration': 5.521},
#  {'text': "design? Which if we're judging the",
#   'start': 1105.84,
#   'duration': 4.719},
#  {'text': 'average user, the iPhone is the phone to',
#   'start': 1108.32,
#   'duration': 4.719},
#  {'text': 'judge the average user on. Like the most',
#   'start': 1110.559,
#   'duration': 4.0},
#  {'text': 'normal people are using it. But what if',
#   'start': 1113.039,
#   'duration': 2.801},
#  {'text': 'I want everything to look like a tennis',
#   'start': 1114.559,
#   'duration': 4.0},
#  {'text': 'ball? Huh? Does he call me a normie? The',
#   'start': 1115.84,
#   'duration': 4.959},
#  {'text': 'real quick, did you notice when they',
#   'start': 1118.559,
#   'duration': 4.161},
#  {'text': 'introduced liquid glass, they called it',
#   'start': 1120.799,
#   'duration': 4.401},
#  {'text': 'an entirely new expressive material?',
#   'start': 1122.72,
#   'duration': 3.839},
#  {'text': 'When that happened, Adam was like,',
#   'start': 1125.2,
#   'duration': 3.76},
#  {'text': '"Material." Expressive, baby. I thought',
#   'start': 1126.559,
#   'duration': 4.561},
#  {'text': 'that was very funny. Material three.',
#   'start': 1128.96,
#   'duration': 4.32},
#  {'text': "Expressive. Um, that's funny. Yeah. So,",
#   'start': 1131.12,
#   'duration': 4.4},
#  {'text': 'they kind of they they drizzled it all',
#   'start': 1133.28,
#   'duration': 3.6},
#  {'text': 'across. Is that the right word?',
#   'start': 1135.52,
#   'duration': 3.68},
#  {'text': 'Drizzled.', 'start': 1136.88, 'duration': 5.76},
#  {'text': 'Megan Fox just just emailed me.',
#   'start': 1139.2,
#   'duration': 5.599},
#  {'text': 'Sorry.', 'start': 1142.64, 'duration': 3.68},
#  {'text': "Okay, we'll read it for the class. It's",
#   'start': 1144.799,
#   'duration': 3.281},
#  {'text': "for a beep. It's for a beeper party",
#   'start': 1146.32,
#   'duration': 4.8},
#  {'text': 'anyway. Um, no, no, no, no, no. Now we',
#   'start': 1148.08,
#   'duration': 4.24},
#  {'text': "need to know. That's You can't just",
#   'start': 1151.12,
#   'duration': 2.88},
#  {'text': 'leave that. You need to read that email.',
#   'start': 1152.32,
#   'duration': 3.04},
#  {'text': 'Just park that in the side and move on.',
#   'start': 1154.0,
#   'duration': 3.52},
#  {'text': 'From Megan Fox, is it the real Megan Fox',
#   'start': 1155.36,
#   'duration': 5.12},
#  {'text': 'or is it like Well, she is real. I mean,',
#   'start': 1157.52,
#   'duration': 4.399},
#  {'text': "she knows you're on this podcast, right?",
#   'start': 1160.48,
#   'duration': 2.96},
# ...
#   'duration': 5.12},
#  {'text': 'Android question because now Call Me',
#   'start': 1784.0,
#   'duration': 4.559},
#  {'text': "Marquez Brownley, I'm using Android and",
#   'start': 1787.039,
#   'duration': 3.681},
#  {'text': 'iOS at the same time right now. But I',
#   'start': 1788.559,
#   'duration': 3.761},
#  {'text': "found that on the Android phone I'm",
#   'start': 1790.72,
#   'duration': 4.0},
#  {'text': 'using um', 'start': 1792.32, 'duration': 4.16},
#  {'text': 'if someone calls me from an unknown',
#   'start': 1794.72,
#   'duration': 4.4},
#  {'text': 'number and that number is listed is',
#   'start': 1796.48,
#   'duration': 4.72},
#  {'text': 'associated with a business in Google',
#   'start': 1799.12,
#   'duration': 3.679},
#  {'text': "Maps, it won't show me the number. It'll",
#   'start': 1801.2,
#   'duration': 2.959},
#  {'text': 'just show me the name of the business.',
#   'start': 1802.799,
#   'duration': 3.521},
#  {'text': 'Is that like standard across all most',
#   'start': 1804.159,
#   'duration': 5.12},
#  {'text': 'Android phones? Yeah. Yeah. Yeah. Good.',
#   'start': 1806.32,
#   'duration': 4.4},
#  {'text': "Doesn't always work perfectly like that.",
#   'start': 1809.279,
#   'duration': 3.361},
#  {'text': "Oh, really? It's worked 100%. Anyway,",
#   'start': 1810.72,
#   'duration': 3.36},
#  {'text': "that's what's that's what made me like",
#   'start': 1812.64,
#   'duration': 2.96},
#  {'text': "feel like I didn't need call screening.",
#   'start': 1814.08,
#   'duration': 3.68},
#  {'text': "I feel like I'd rather have that than",
#   'start': 1815.6,
#   'duration': 4.16},
#  {'text': 'call. But even like a random delivery',
#   'start': 1817.76,
#   'duration': 4.159},
#  {'text': "person where it won't show up as UPS,",
#   'start': 1819.76,
#   'duration': 3.76},
#  {'text': "but it's a delivery guy needs to like",
#   'start': 1821.919,
#   'duration': 3.441},
#  {'text': 'get in touch. The poor Door Dash people',
#   'start': 1823.52,
#   'duration': 3.92},
#  {'text': 'have to talk to Siri every time. Like,',
#   'start': 1825.36,
#   'duration': 5.52},
#  {'text': "I'm at your door. Please find. That's",
#   'start': 1827.44,
#   'duration': 5.04},
#  {'text': 'the example they gave in the keynote. It',
#   'start': 1830.88,
#   'duration': 3.679},
#  {'text': 'was, "Hi, this is Greg downstairs with a',
#   'start': 1832.48,
#   'duration': 3.52},
#  {'text': "flower delivery. I'll wait another",
#   'start': 1834.559,
#   'duration': 2.801},
#  {'text': 'minute before I have to move on to the',
#   'start': 1836.0,
#   'duration': 4.159},
#  {'text': 'next one. Yeah, but by the time you',
#   'start': 1837.36,
#   'duration': 4.88},
#  {'text': "actually pick up the minute, it's over.",
#   'start': 1840.159,
#   'duration': 3.921},
#  {'text': 'Yeah. Can I just say my favorite subplot',
#   'start': 1842.24,
#   'duration': 3.6},
#  {'text': 'of this podcast in the last couple weeks',
#   'start': 1844.08,
#   'duration': 3.68},
#  {'text': 'has been Ellis discovering Android',
#   'start': 1845.84,
#   'duration': 5.04},
#  {'text': 'features real time. Dope felt like Yeah,',
#   'start': 1847.76,
#   'duration': 5.36},
#  {'text': "that's strap in. There's a lot more",
#   'start': 1850.88,
#   'duration': 4.0},
#  {'text': "coming. Yeah, there's a lot more coming.",
#   'start': 1853.12,
#   'duration': 4.48},
#  {'text': "I do also think it's very beautiful that",
#   'start': 1854.88,
#   'duration': 5.279},
#  {'text': 'Google literally has they have it have',
#   'start': 1857.6,
#   'duration': 4.4},
#  {'text': 'had this for so long that people have',
#   'start': 1860.159,
#   'duration': 3.841},
#  {'text': 'just solidified the naming schemes that',
#   'start': 1862.0,
#   'duration': 3.919},
#  {'text': 'Google have given these features. So I',
#   'start': 1864.0,
#   'duration': 3.36},
#  {'text': 'was in a briefing where they were like',
#   'start': 1865.919,
#   'duration': 3.041},
#  {'text': 'talking about all these features and',
#   'start': 1867.36,
#   'duration': 2.799},
#  {'text': 'someone was like can you explain how',
#   'start': 1868.96,
#   'duration': 2.719},
#  {'text': "call screening works and they're like so",
#   'start': 1870.159,
#   'duration': 5.12},
#  {'text': "it's not called screening", 'start': 1871.679, 'duration': 5.041},
#  {'text': "it's called this new thing. It was",
#   'start': 1875.279,
#   'duration': 3.601},
#  {'text': 'amazing. Yeah. The other one is hold',
#   'start': 1876.72,
#   'duration': 3.679},
#  {'text': "assist is what they're calling it",
#   'start': 1878.88,
#   'duration': 2.96},
#  {'text': 'literally hold for me too. Yeah. Hold',
#   'start': 1880.399,
#   'duration': 2.801},
#  {'text': 'for me is the Google branded version,',
#   'start': 1881.84,
#   'duration': 3.28},
#  {'text': "but you're on you're on a call and you",
#   'start': 1883.2,
#   'duration': 4.0},
#  {'text': "go, uh, it's like 20 minutes of hold",
#   'start': 1885.12,
#   'duration': 3.6},
#  {'text': "music. I don't feel like waiting. You",
#   'start': 1887.2,
#   'duration': 3.28},
#  {'text': 'just have it hold for you and as soon as',
#   'start': 1888.72,
#   'duration': 3.76},
#  {'text': 'somebody picks up, it will ring you and',
#   'start': 1890.48,
#   'duration': 3.679},
#  {'text': 'you can join the call again. So good.',
#   'start': 1892.48,
#   'duration': 4.16},
#  {'text': 'Thanks for holding for me. So good. So',
#   'start': 1894.159,
#   'duration': 4.64},
#  {'text': 'those are nice. Uh, what else is new to',
#   'start': 1896.64,
#   'duration': 3.84},
#  {'text': "iOS 26? Well, in the phone app, there's",
#   'start': 1898.799,
#   'duration': 4.48},
#  {'text': 'also a new phone app design. So it shows',
#   'start': 1900.48,
#   'duration': 5.28},
#  {'text': "like there's now a contacts cards like",
#   'start': 1903.279,
#   'duration': 4.64},
#  {'text': 'favorites list at the top, which is',
#   'start': 1905.76,
#   'duration': 4.72},
#  {'text': 'nice. Um, yeah, they they redesigned it',
#   'start': 1907.919,
#   'duration': 4.321},
#  {'text': "a little bit. It's a lot simpler.",
#   'start': 1910.48,
#   'duration': 3.199},
#  {'text': "There's only like three things at the",
#   'start': 1912.24,
#   'duration': 3.039},
#  {'text': 'bottom now. And then a little search bar',
#   'start': 1913.679,
#   'duration': 6.321},
#  {'text': 'has the new uh liquid glass design. Uh',
#   'start': 1915.279,
#   'duration': 6.721},
#  {'text': 'and they also separated calls, miss',
#   'start': 1920.0,
#   'duration': 3.919},
#  {'text': 'calls, voicemails, spam into these',
#   'start': 1922.0,
#   'duration': 3.84},
#  {'text': 'little sub menus. So this is actually a',
#   'start': 1923.919,
#   'duration': 4.321},
#  {'text': 'theme throughout quite a bit of the OS',
#   'start': 1925.84,
#   'duration': 4.079},
#  {'text': 'where they have created these sub menus',
#   'start': 1928.24,
#   'duration': 3.2},
#  {'text': "for things that you probably don't want",
#   'start': 1929.919,
#   'duration': 3.36},
#  {'text': 'to deal with. For example, segue into',
#   'start': 1931.44,
#   'duration': 4.719},
#  {'text': 'messages app. Uh in the messages, thank',
#   'start': 1933.279,
#   'duration': 4.961},
#  {'text': 'you. Very good. In the messages app,',
#   'start': 1936.159,
#   'duration': 4.161},
#  {'text': "they've also included this submen that",
#   'start': 1938.24,
#   'duration': 4.0},
#  {'text': 'really is the hamburger menu but tilted',
#   'start': 1940.32,
#   'duration': 5.599},
#  {'text': '90°. Uh, and when you click it, it also',
#   'start': 1942.24,
#   'duration': 6.72},
#  {'text': 'now has a unknown senders folder. Wait,',
#   'start': 1945.919,
#   'duration': 5.281},
#  {'text': 'what? Yeah, in the messages app for like',
#   'start': 1948.96,
#   'duration': 5.36},
#  {'text': 'hamburger menu tilted 90°. Oh, wait. No,',
#   'start': 1951.2,
#   'duration': 4.959},
#  {'text': "it's not tilted 90°. No, it's it's just",
#   'start': 1954.32,
#   'duration': 4.079},
#  {'text': "the hamburger menu, but it's not all",
#   'start': 1956.159,
#   'duration': 4.24},
#  {'text': "it's not all even. It's cascading. Yeah.",
#   'start': 1958.399,
#   'duration': 4.081},
#  {'text': "Yeah. So, it's different. I was just",
#   'start': 1960.399,
#   'duration': 3.921},
#  {'text': 'laughing at like hamburger menu, like',
#   'start': 1962.48,
#   'duration': 4.64},
#  {'text': 'cheeseburger, bacon burger. like it just',
#   'start': 1964.32,
#   'duration': 5.04},
#  {'text': 'the pork menu and like a food item pork',
#   'start': 1967.12,
#   'duration': 4.48},
#  {'text': 'burger. But anyway, so yeah, now I think',
#   'start': 1969.36,
#   'duration': 5.28},
#  {'text': 'that a big theme of this that is like un',
#   'start': 1971.6,
#   'duration': 4.959},
#  {'text': "sort of they unspoken is that they're",
#   'start': 1974.64,
#   'duration': 3.519},
#  {'text': "trying to get they're trying to fight",
#   'start': 1976.559,
#   'duration': 4.321},
#  {'text': 'like spammers basically. So just like in',
#   'start': 1978.159,
#   'duration': 4.0},
#  {'text': 'the phone app how they had like the',
#   'start': 1980.88,
#   'duration': 2.72},
#  {'text': 'unknown senders thing and they have all',
#   'start': 1982.159,
#   'duration': 3.201},
#  {'text': 'those features where unknown senders',
#   'start': 1983.6,
#   'duration': 4.72},
#  {'text': "can't get to you, they now have a like",
#   'start': 1985.36,
#   'duration': 6.0},
#  {'text': 'spam and unknown senders folder that are',
#   'start': 1988.32,
#   'duration': 5.199},
#  {'text': 'here. They also have a filter for unread',
#   'start': 1991.36,
#   'duration': 3.76},
#  {'text': 'which is very nice. So everything will',
#   'start': 1993.519,
#   'duration': 4.321},
#  {'text': "trickle to the top. And uh yeah, it's",
#   'start': 1995.12,
#   'duration': 4.799},
#  {'text': "it's different now. I keep getting",
#   'start': 1997.84,
#   'duration': 4.319},
#  {'text': "tripped up because the s there's a",
#   'start': 1999.919,
#   'duration': 4.0},
#  {'text': 'search button at the bottom now which',
#   'start': 2002.159,
#   'duration': 3.281},
#  {'text': 'you have to click to like be able to',
#   'start': 2003.919,
#   'duration': 4.081},
#  {'text': 'find um other people and it used to be',
#   'start': 2005.44,
#   'duration': 4.56},
#  {'text': 'at the top. But overall, I really like',
#   'start': 2008.0,
#   'duration': 4.159},
#  {'text': 'the messages redesign. Also, if you want',
#   'start': 2010.0,
#   'duration': 4.399},
#  {'text': 'to see something really chaotic, they',
#   'start': 2012.159,
#   'duration': 4.4},
#  {'text': 'added backgrounds.', 'start': 2014.399, 'duration': 4.4},
#  {'text': 'Oh god, they added backgrounds inside of',
#   'start': 2016.559,
#   'duration': 5.441},
#  {'text': 'an iMessage thread. I have this Aurora',
#   'start': 2018.799,
#   'duration': 5.12},
#  {'text': 'that took like longer to load than I',
#   'start': 2022.0,
#   'duration': 4.0},
#  {'text': 'would have liked. Oh, yes it did, baby.',
#   'start': 2023.919,
#   'duration': 4.561},
#  {'text': 'Maybe a beta thing. Um, so we have a',
#   'start': 2026.0,
#   'duration': 4.64},
#  {'text': 'live Aurora going on here. They have',
#   'start': 2028.48,
#   'duration': 4.079},
#  {'text': 'like live A lot of this really feels',
#   'start': 2030.64,
#   'duration': 3.84},
#  {'text': 'like early Android stuff. Well, this is',
#   'start': 2032.559,
#   'duration': 3.681},
#  {'text': 'WhatsApp. Just basically them adding',
#   'start': 2034.48,
#   'duration': 3.52},
#  {'text': 'feature like the multiple people in a',
#   'start': 2036.24,
#   'duration': 4.24},
#  {'text': 'group chat typing indicators just things',
#   'start': 2038.0,
#   'duration': 5.12},
#  {'text': 'other group chats have had for a while,',
#   'start': 2040.48,
#   'duration': 4.559},
#  {'text': 'backgrounds, polls, all these things',
#   'start': 2043.12,
#   'duration': 3.76},
#  {'text': 'that you could do in other chat apps',
#   'start': 2045.039,
#   'duration': 3.761},
#  {'text': "that you can now do iMessage. Can't wait",
#   'start': 2046.88,
#   'duration': 4.32},
#  {'text': 'to see what Android people get in a',
#   'start': 2048.8,
#   'duration': 4.0},
#  {'text': 'group message that gets sent a poll.',
#   'start': 2051.2,
#   'duration': 3.28},
#  {'text': 'Actually, can you test it right now? Can',
#   'start': 2052.8,
#   'duration': 3.599},
#  {'text': 'you send a poll? Yeah. Yeah. Throw me',
#   'start': 2054.48,
#   'duration': 3.359},
#  {'text': 'and Andrew in a group chat and see what',
#   'start': 2056.399,
#   'duration': 3.121},
#  {'text': "the poll looks like. It won't it won't",
#   'start': 2057.839,
#   'duration': 3.84},
#  {'text': 'show up for Andrew, right? Well, am I',
#   'start': 2059.52,
#   'duration': 4.319},
#  {'text': "going to get a message that's like David",
#   'start': 2061.679,
#   'duration': 5.2},
#  {'text': 'posted a poll A,', 'start': 2063.839, 'duration': 6.0},
#  {'text': "B, C, and read out everyone's votes one",
#   'start': 2066.879,
#   'duration': 4.24},
#  {'text': 'by one. That would be horrible. That',
#   'start': 2069.839,
#   'duration': 2.8},
#  {'text': 'would be very funny. Okay, while David',
#   'start': 2071.119,
#   'duration': 3.121},
#  {'text': 'sets that up, uh we have been avoiding',
#   'start': 2072.639,
#   'duration': 3.921},
#  {'text': "the elephant in the room. Um, so I'm",
#   'start': 2074.24,
#   'duration': 4.32},
#  {'text': "glad that we've gotten to this point.",
#   'start': 2076.56,
#   'duration': 6.16},
#  {'text': 'Uh, live translation.', 'start': 2078.56, 'duration': 8.079},
#  {'text': "It's the year of live translation. 2025.",
#   'start': 2082.72,
#   'duration': 5.52},
#  {'text': "We didn't know it was going to happen so",
#   'start': 2086.639,
#   'duration': 4.321},
#  {'text': 'fast, but clearly one of us did. Yeah.',
#   'start': 2088.24,
#   'duration': 5.839},
#  {'text': 'Ondevice models are proving useful in',
#   'start': 2090.96,
#   'duration': 7.119},
#  {'text': 'messages, FaceTime, and phone. In all',
#   'start': 2094.079,
#   'duration': 6.0},
#  {'text': "the ways you're imagining, you can now",
#   'start': 2098.079,
#   'duration': 3.441},
#  {'text': 'have a conversation with someone who',
#   'start': 2100.079,
#   'duration': 3.04},
#  {'text': 'speaks a different language. It will',
#   'start': 2101.52,
#   'duration': 2.88},
#  {'text': "understand what you're saying and",
#   'start': 2103.119,
#   'duration': 3.041},
#  {'text': 'translate it in your voice and then',
#   'start': 2104.4,
#   'duration': 3.04},
#  {'text': "understand what the other person's",
#   'start': 2106.16,
#   'duration': 2.72},
#  {'text': 'saying and translate it so that you can',
#   'start': 2107.44,
#   'duration': 4.32},
#  {'text': 'hear it. Boom. Anyone in the world can',
#   'start': 2108.88,
#   'duration': 4.8},
#  {'text': 'talk to anyone in the world through the',
#   'start': 2111.76,
#   'duration': 4.16},
#  {'text': 'live translate feature. Was it anyone in',
#   'start': 2113.68,
#   'duration': 3.84},
#  {'text': "the world? It's not all I just want to",
#   'start': 2115.92,
#   'duration': 4.08},
#  {'text': 'say', 'start': 2117.52, 'duration': 6.16},
#  {'text': 'translate. you know, as the the biggest',
#   'start': 2120.0,
#   'duration': 5.76},
#  {'text': 'believer and strongest backer of live',
#   'start': 2123.68,
#   'duration': 4.48},
#  {'text': "translation, as someone who's been in",
#   'start': 2125.76,
#   'duration': 5.28},
#  {'text': 'the trenches rooting for this hand over',
#   'start': 2128.16,
#   'duration': 7.28},
#  {'text': "fist for for years. Uh you're welcome,",
#   'start': 2131.04,
#   'duration': 7.28},
#  {'text': 'world. Uh you know, I think I think',
#   'start': 2135.44,
#   'duration': 6.48},
#  {'text': 'because of me bringing this about, all',
#   'start': 2138.32,
#   'duration': 6.799},
#  {'text': "wars will end. Um we'll achieve world",
#   'start': 2141.92,
#   'duration': 5.36},
#  {'text': 'peace at like a record rate. No one will',
#   'start': 2145.119,
#   'duration': 4.24},
#  {'text': 'be hungry anymore. All those translation',
#   'start': 2147.28,
#   'duration': 4.319},
#  {'text': "errors because of Yeah, because that's",
#   'start': 2149.359,
#   'duration': 5.041},
#  {'text': 'where it all went wrong, you know. Now',
#   'start': 2151.599,
#   'duration': 4.401},
#  {'text': 'we just got to make sure everyone has',
#   'start': 2154.4,
#   'duration': 4.64},
#  {'text': 'AirPods and an iPhone and is willing to',
#   'start': 2156.0,
#   'duration': 6.48},
#  ...]

# %% [markdown]
# ### Step 1b - Indexing (Text Splitting)

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size = 1000, chunk_overlap = 200)
chunks = splitter.create_documents([transcript])

# %%
len(chunks)
# Out:
# 123

# %%
chunks[0]
# Out:
# Document(metadata={}, page_content="They drizzled it all across. Is that the right word? Drizzled. Megan Fox just just emailed me. Sorry. Okay, we'll read it for the class. It's for a beep. It's for a beeper party. Anyway, um No, no, no, no, no. Now we need to know. That's You can't just leave that. You need to read that email. Just park that in the side and move on. Megan Fox. Is it the real Megan Fox or is it like Well, she is real. Yo, what is up people of the internet? Welcome back to another episode of the Waveform Podcast. We're your hosts. I'm Marquez. I'm Andrew. And I'm David. This was WWDC week. Apple had their uh their their software announcement festivities slash an what? I don't know what you want to call it. It's a developer conference, but it's also like unveiling a bunch of new stuff. Ragger. And uh yeah, there's there's lots to talk about. There's liquid glass. There is iPad turning into a computer finally. You guys are stuff. I didn't do anything. You didn't say it yet. Uh fake workout buddies.")

# %% [markdown]
# ### Step 1c and 1d - Indexing (Embedding Generation and Storing in Vector Store)

# %%
embedding = OpenAIEmbeddings(model="text-embedding-3-small" )
vector_store = FAISS.from_documents(chunks, embedding)

# %%
vector_store.index_to_docstore_id
# Out:
# {0: 'f892ca06-db8f-4466-acf6-b70c78db74ed',
#  1: '0f234cfe-0ea4-4bf4-a19d-7cacc06179b9',
#  2: '7314792c-e1eb-4d81-9506-5bc22a0bd7d1',
#  3: 'f0edf2cf-d6dc-43d5-b6cb-4cd300b4e9cf',
#  4: 'afa15277-7044-4938-9936-bdcfa5397da1',
#  5: 'c8721191-fcc5-487a-8e3d-7184f729be87',
#  6: '269ea48b-9139-459b-938f-7cad936a31e9',
#  7: '120a2c71-757f-443c-bdb9-64913fed2467',
#  8: '2a7f38de-0bc0-40bb-b060-4a7960a280ed',
#  9: 'a37b3293-b168-40d7-8889-989148a2dde3',
#  10: 'bc614be9-7aee-4dee-bb6b-451661608cb5',
#  11: 'e1bda58a-257f-4684-b81b-ec3978c9e436',
#  12: 'b43ea247-2b83-4d85-a81a-7b058dcf962e',
#  13: '0d1f2ca0-13bd-4b52-b760-87d1bdf4690d',
#  14: '9c5f3052-6a70-4340-83ea-2f715ab7b04b',
#  15: '4ce1543f-a839-4f08-916f-43821241fda0',
#  16: 'b798e64c-755e-45ce-b3b6-4deae79f3d29',
#  17: '1481e29c-957a-426b-b1c9-3b9a6b7c1eae',
#  18: 'e1e1d24e-60b6-48bb-aa94-1afda83af45f',
#  19: '39c93263-e9f9-424e-ad13-758434829620',
#  20: '70ed8bab-d2ab-4188-9e41-d131ac3748e0',
#  21: '59910ea8-7c7f-45e6-b46f-cfad514c4c26',
#  22: '93691e20-232d-4013-9a22-4fd6c680124a',
#  23: 'ae56e707-b0bb-4eba-908e-abb5c825c3a3',
#  24: '6731b770-cf11-44f6-83ba-a2e28fde676d',
#  25: '269f6256-0356-4d5c-89bc-1f92a7454614',
#  26: 'af338687-51fa-40fd-9bce-bb08f25cf48f',
#  27: 'c73712bb-f926-4ee4-8581-0c3f3012a9f6',
#  28: '8f6de55c-b3a9-4ba5-b57b-d938949b76bd',
#  29: 'fe750f62-a511-48ee-9450-30067bec3b4d',
#  30: 'f5fe23f5-7cf3-4ec8-ad18-aa8f0d335d06',
#  31: '163d5e60-3000-49ed-b4c5-3cdfa0f12175',
#  32: 'db9ca1ec-7d93-4f2a-9a50-6bf801fe565d',
#  33: '20cea61c-8e66-4060-9c38-3319304f5ffc',
#  34: '5f6d8ee5-dca5-44a9-8689-ead8d6f4db72',
#  35: '1a2f00f5-3e5f-4d8e-adcd-e983d20ab91c',
#  36: 'db6cda45-3cb2-4540-94c2-8223936d3603',
#  37: '318119a5-fb19-401c-83b7-d7723734958a',
#  38: '29a7be23-e40b-45d0-9bef-730628e46b10',
#  39: '561193e6-da2f-46ab-82a7-fe8e806b87bc',
#  40: 'ccb3350e-cf33-4295-b898-5a7ba58181bb',
#  41: '6d1a3f2f-9c48-47ab-a521-095103126f14',
#  42: 'a7e6ba73-7cc5-41e9-a1c4-2cdf0e15d0ed',
#  43: '87240a2f-1ebe-46dd-9b67-cd249a45c5bd',
#  44: '24cb2409-e51f-4a3f-bd45-b7d8b176016b',
#  45: '511b818b-3424-48fe-9534-adf2736e2ec6',
#  46: 'c86b52e4-bf94-4e78-b803-f4fb485b01e9',
#  47: 'b15826db-041a-4c4f-8cc7-414c09a498ad',
#  48: 'e3b51d61-9c76-45a5-b3b7-446bb20d3b72',
#  49: 'd5a08523-1f82-4c74-8ad9-e59cd9765c27',
#  50: '33d9f21f-cdd7-49a7-bf28-61295a6be533',
#  51: '1af246e8-aa42-4d61-b1b1-79e2efe39b83',
#  52: 'd946bb5a-04a3-4692-90e6-07f8f9e64cc5',
#  53: '6e3af78d-d0da-4f4d-9f27-cbe12c57c563',
#  54: '8d8e1cf1-6248-46a4-9c7c-9fe908f1a60f',
#  55: '1441845f-c1c9-4771-9b36-c6c9027103c1',
#  56: 'f04e4ab0-9bf9-4e4b-9947-b16f68072675',
#  57: 'f59a1aa0-91b9-4eed-95f0-ff517cdae629',
#  58: 'eae15d0c-1c30-40f6-b5a4-b4ef8f59a281',
#  59: '06d3b36f-e25a-48a3-8746-5fae73a8451c',
#  60: 'a309f250-d8c9-41e2-bfc0-f19b7424c5a8',
#  61: 'f3af2aff-706f-43b6-adb6-4cf2ce015c1f',
#  62: 'b482be16-8f13-4bc1-922a-6cfc17c22ddd',
#  63: '821b5ae8-b64f-4f18-bccb-f120e0ef6b39',
#  64: '69413649-62ab-4c67-962c-c03bd2486c7c',
#  65: '1882a42a-9e9a-4fe6-a83a-0d01304da350',
#  66: '4a7d2161-bbce-4927-8cfc-40204ec96d8b',
#  67: 'c3a0c3e2-aaa9-4e75-a56b-fd17f373609a',
#  68: '8e0c8c18-dc40-434d-a7bd-b6498433d24d',
#  69: 'c68444d8-70ce-423e-bca2-3445af276ad2',
#  70: 'a0434c72-fd3b-4889-b82a-51a2734e519d',
#  71: '926acd7f-2f56-40da-a73a-01da7a2dc169',
#  72: '9b4947c8-84ca-4952-9798-4b7623fd8549',
#  73: '52b2bee7-82f9-4f6e-810e-ecc6c6873356',
#  74: 'e00b91af-74e0-461f-abda-8cb0b3def411',
#  75: '9343b77d-5636-4ea5-a3b6-3ff04d3a1d4e',
#  76: 'b3070efc-c262-4950-93da-744d60c0abbd',
#  77: '48568607-cdae-49f2-9ec2-0aa4249d1b95',
#  78: '498b9386-0737-4e82-ba70-7d2206593e36',
#  79: '4d9e1e0f-6d3b-414f-b719-0f665eb468a4',
#  80: 'c8b91f6f-b587-4f2a-be1c-cd437bda2339',
#  81: 'f0fc7f49-c03f-478e-bacd-328b58a14916',
#  82: '9951431d-e828-44c2-9170-11a726b2eb8d',
#  83: 'e0519a9c-a419-45ef-9d92-e80bc528ef69',
#  84: '916b4bd3-f369-4dc4-94bb-931a461e5287',
#  85: '940c4811-ab68-4d25-93e1-d1a89f49e101',
#  86: '6c5d9343-7d20-4145-8221-2ff04e58fc29',
#  87: '7b2f478f-2fe5-4955-836e-be69ba4402e1',
#  88: '99d3bcdf-55c2-4c7d-bb25-36f436d1e1aa',
#  89: '656769eb-3a34-4e8d-8bfb-2e678220afa0',
#  90: '388a6023-6c41-4cd5-b24b-9be161713b7b',
#  91: '6d65ac40-09b1-442e-a0bb-da4a478d00a5',
#  92: 'ff4eb92c-d15a-43b1-8825-ad6f0679492e',
#  93: 'be6339b0-7105-4081-af7f-623a896217ad',
#  94: '774f00ef-abdd-46dd-8e2a-8395cabe6eda',
#  95: '7a66ffdf-af96-4825-a981-726ba6833c73',
#  96: '5db0dd2e-e8c5-42fd-8e19-9574ce4a769d',
#  97: '4f2136a4-e0d1-4bfd-b01a-cf5d85c03f15',
#  98: '60555e05-76f1-421a-b77e-d7b753e839c1',
#  99: '280a1806-45b4-4f4b-ac72-e9de8e04a465',
#  100: 'e5d11010-f4eb-465c-9bb7-9ffe5898f3cd',
#  101: '033aae52-3b49-4578-830e-1d7aca7bbaad',
#  102: '957a7dde-18f2-400b-86cd-ff9184d790e5',
#  103: '7aaa13a4-f294-4a52-a73d-95ea849581b7',
#  104: '31b83237-9bf5-41e6-9d6e-3023249f3665',
#  105: 'fd5c2e10-eb31-443c-aa33-8f01a8c9926c',
#  106: 'bbda2dcc-1bcb-44a0-9766-b1dbcb5191d6',
#  107: '440a69d0-4fda-4faa-a789-3389116a4eb2',
#  108: 'fc3f3385-66b6-41a2-811c-fb06f6012593',
#  109: '20167695-2648-4647-a048-f466f1bc1319',
#  110: '7ff3e94c-53f5-4a46-a254-6f76c2f7bc2a',
#  111: '0ac16e85-c43c-487d-8742-58caf9bbaeca',
#  112: '793851f1-1c0b-4f8c-be2b-7ecf40049ae9',
#  113: '15dbb94d-6f16-49c6-a325-f9881bd0c420',
#  114: '5468ea94-e0e6-4eb6-9f86-637f6567b3e3',
#  115: 'fb73cd08-4202-4968-be13-8d2d08352a30',
#  116: '501b9429-982d-4470-9747-2b4c38782f3e',
#  117: '1a430a93-6694-4a1a-a7be-4a45e5ea1a58',
#  118: '3597220c-e81d-417b-8ddb-b8e2b8878d34',
#  119: '79183f78-f9f5-4fa5-831e-d07a30a15e3b',
#  120: '1f2f1c47-e796-43e2-9fe3-70b772a6e644',
#  121: 'db8260f3-afa4-4b6d-b4ae-d145f78a9ff1',
#  122: '90547704-e051-4dae-aaf9-4468a1bd7776'}

# %%
# vector_store.get_by_ids([' '])

# %% [markdown]
# ### Step2 - Retrieval

# %%
retriever = vector_store.as_retriever(search_type = "similarity", search_kwargs = {"k":4})

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x00000280AC97D7D0>, search_kwargs={'k': 4})

# %%
retriever.invoke('What features did apple release in there overhaul iOS')
# Out:
# [Document(id='774f00ef-abdd-46dd-8e2a-8395cabe6eda', metadata={}, page_content='thing. It was kind of shocking. It was just teared up. Crazy. Like they did all they added full free form windows. Like you can just drag from the corner and make a bunch of windows as whatever size you want. uh multiple overlapping windows, oncreen, offscreen, full screen. They also added a menu bar at the top and window controls on those windows. And yeah, that the stoplight menu for like closing or minimizing or change the size of windows. There\'s a new redesigned files app. There is a new audio input selector, which I also confirmed will work with Bluetooth microphones. I used to have to I\'ve been paying for apps to do this for like years. Every time I test Bluetooth headphones, I\'m like, "How do I do this test? This is going to be the worst part." Yeah. Um, there are so many things in iPad OS. Uh, the pre the new preview app, you can export to different file sizes and types. Like all of this stuff, uh, the new files app can let you sort by or organize by showing different types'),
#  Document(id='a7e6ba73-7cc5-41e9-a1c4-2cdf0e15d0ed', metadata={}, page_content="for me. So good. So those are nice. Uh, what else is new to iOS 26? Well, in the phone app, there's also a new phone app design. So it shows like there's now a contacts cards like favorites list at the top, which is nice. Um, yeah, they they redesigned it a little bit. It's a lot simpler. There's only like three things at the bottom now. And then a little search bar has the new uh liquid glass design. Uh and they also separated calls, miss calls, voicemails, spam into these little sub menus. So this is actually a theme throughout quite a bit of the OS where they have created these sub menus for things that you probably don't want to deal with. For example, segue into messages app. Uh in the messages, thank you. Very good. In the messages app, they've also included this submen that really is the hamburger menu but tilted 90°. Uh, and when you click it, it also now has a unknown senders folder. Wait, what? Yeah, in the messages app for like hamburger menu tilted 90°. Oh, wait. No, it's"),
#  Document(id='ff4eb92c-d15a-43b1-8825-ad6f0679492e', metadata={}, page_content="So, that's cood.io/wave and get six months of the team plan for free. cod.io/wave. All right, welcome back. We've got one more big OS update to talk about from Apple this week and that is the iPad. Now, the history of iPad updates has been very consistent. We've got maybe five or six years of iPads under our belt where I review the iPad and I say the same thing that I said the last year when I reviewed the iPad, which is, man, this hardware is so good, so impressive, so thin, so fast, beautiful screen, but it's still an iPad. I always say that line, but it's still an iPad. And that's because it's still the same iOS on steroids kind of software where if you were hoping to make it your computer, it is clearly not up to that. It's not designed for that. And heck, it's Apple. Why would we expect them to do that? They make computers. If they wanted to sell you a computer, it's over there. It's called the Mac. So, they're always so separate for so long. And I've watched so many YouTube"),
#  Document(id='120a2c71-757f-443c-bdb9-64913fed2467', metadata={}, page_content="it was a lot. It was quite a bit. I think it was enough to have some thoughts and some meat to chew on while we also wait for the rest of Apple intelligence stuff and more AI features. I think the way that they addressed it was actually very smart because they kind of took the like bad is forever and delay is temporary approach. Just saying like we want this to be good. We have quality standards. Just wait for it. I think that's always the best way to delay things honestly. Sure. Uh how it affects their stock price, I have no idea. It didn't do very well, I don't think, when it got announced. You know, that's how it is. Anyway, well, we could talk about any number of these 26 versions of OS first, but I think the one that most people want to talk about is iOS 26. So, we should probably just jump in there. So, liquid new Yeah, liquid liquid glass everywhere. Liquid glass is uh the new aesthetic that is specifically the transparent and refractive almost material design of all of these")]

# %% [markdown]
# ### Step3 Augmentation

# %%
model = ChatOpenAI(model = "gpt-4.1-nano-2025-04-14",  temperature = 0.2, max_completion_tokens = 200)

# %%
prompt = PromptTemplate(
    template="""
      You are a helpful assistant.
      Answer ONLY from the provided transcript context.
      If the context is insufficient, just say you don't know.

      {context}
      Question: {question}
    """,
    input_variables = ['context','question']
)

# %%
question = "What features did apple release in there overhaul iOS"
retrieved_docs = retriever.invoke(question)

# %%
retrieved_docs
# Out:
# [Document(id='774f00ef-abdd-46dd-8e2a-8395cabe6eda', metadata={}, page_content='thing. It was kind of shocking. It was just teared up. Crazy. Like they did all they added full free form windows. Like you can just drag from the corner and make a bunch of windows as whatever size you want. uh multiple overlapping windows, oncreen, offscreen, full screen. They also added a menu bar at the top and window controls on those windows. And yeah, that the stoplight menu for like closing or minimizing or change the size of windows. There\'s a new redesigned files app. There is a new audio input selector, which I also confirmed will work with Bluetooth microphones. I used to have to I\'ve been paying for apps to do this for like years. Every time I test Bluetooth headphones, I\'m like, "How do I do this test? This is going to be the worst part." Yeah. Um, there are so many things in iPad OS. Uh, the pre the new preview app, you can export to different file sizes and types. Like all of this stuff, uh, the new files app can let you sort by or organize by showing different types'),
#  Document(id='a7e6ba73-7cc5-41e9-a1c4-2cdf0e15d0ed', metadata={}, page_content="for me. So good. So those are nice. Uh, what else is new to iOS 26? Well, in the phone app, there's also a new phone app design. So it shows like there's now a contacts cards like favorites list at the top, which is nice. Um, yeah, they they redesigned it a little bit. It's a lot simpler. There's only like three things at the bottom now. And then a little search bar has the new uh liquid glass design. Uh and they also separated calls, miss calls, voicemails, spam into these little sub menus. So this is actually a theme throughout quite a bit of the OS where they have created these sub menus for things that you probably don't want to deal with. For example, segue into messages app. Uh in the messages, thank you. Very good. In the messages app, they've also included this submen that really is the hamburger menu but tilted 90°. Uh, and when you click it, it also now has a unknown senders folder. Wait, what? Yeah, in the messages app for like hamburger menu tilted 90°. Oh, wait. No, it's"),
#  Document(id='ff4eb92c-d15a-43b1-8825-ad6f0679492e', metadata={}, page_content="So, that's cood.io/wave and get six months of the team plan for free. cod.io/wave. All right, welcome back. We've got one more big OS update to talk about from Apple this week and that is the iPad. Now, the history of iPad updates has been very consistent. We've got maybe five or six years of iPads under our belt where I review the iPad and I say the same thing that I said the last year when I reviewed the iPad, which is, man, this hardware is so good, so impressive, so thin, so fast, beautiful screen, but it's still an iPad. I always say that line, but it's still an iPad. And that's because it's still the same iOS on steroids kind of software where if you were hoping to make it your computer, it is clearly not up to that. It's not designed for that. And heck, it's Apple. Why would we expect them to do that? They make computers. If they wanted to sell you a computer, it's over there. It's called the Mac. So, they're always so separate for so long. And I've watched so many YouTube"),
#  Document(id='120a2c71-757f-443c-bdb9-64913fed2467', metadata={}, page_content="it was a lot. It was quite a bit. I think it was enough to have some thoughts and some meat to chew on while we also wait for the rest of Apple intelligence stuff and more AI features. I think the way that they addressed it was actually very smart because they kind of took the like bad is forever and delay is temporary approach. Just saying like we want this to be good. We have quality standards. Just wait for it. I think that's always the best way to delay things honestly. Sure. Uh how it affects their stock price, I have no idea. It didn't do very well, I don't think, when it got announced. You know, that's how it is. Anyway, well, we could talk about any number of these 26 versions of OS first, but I think the one that most people want to talk about is iOS 26. So, we should probably just jump in there. So, liquid new Yeah, liquid liquid glass everywhere. Liquid glass is uh the new aesthetic that is specifically the transparent and refractive almost material design of all of these")]

# %%
context_text = "\n\n".join(doc.page_content for doc in retrieved_docs)
context_text
# Out:
# 'thing. It was kind of shocking. It was just teared up. Crazy. Like they did all they added full free form windows. Like you can just drag from the corner and make a bunch of windows as whatever size you want. uh multiple overlapping windows, oncreen, offscreen, full screen. They also added a menu bar at the top and window controls on those windows. And yeah, that the stoplight menu for like closing or minimizing or change the size of windows. There\'s a new redesigned files app. There is a new audio input selector, which I also confirmed will work with Bluetooth microphones. I used to have to I\'ve been paying for apps to do this for like years. Every time I test Bluetooth headphones, I\'m like, "How do I do this test? This is going to be the worst part." Yeah. Um, there are so many things in iPad OS. Uh, the pre the new preview app, you can export to different file sizes and types. Like all of this stuff, uh, the new files app can let you sort by or organize by showing different types\n\nfor me. So good. So those are nice. Uh, what else is new to iOS 26? Well, in the phone app, there\'s also a new phone app design. So it shows like there\'s now a contacts cards like favorites list at the top, which is nice. Um, yeah, they they redesigned it a little bit. It\'s a lot simpler. There\'s only like three things at the bottom now. And then a little search bar has the new uh liquid glass design. Uh and they also separated calls, miss calls, voicemails, spam into these little sub menus. So this is actually a theme throughout quite a bit of the OS where they have created these sub menus for things that you probably don\'t want to deal with. For example, segue into messages app. Uh in the messages, thank you. Very good. In the messages app, they\'ve also included this submen that really is the hamburger menu but tilted 90°. Uh, and when you click it, it also now has a unknown senders folder. Wait, what? Yeah, in the messages app for like hamburger menu tilted 90°. Oh, wait. No, it\'s\n\nSo, that\'s cood.io/wave and get six months of the team plan for free. cod.io/wave. All right, welcome back. We\'ve got one more big OS update to talk about from Apple this week and that is the iPad. Now, the history of iPad updates has been very consistent. We\'ve got maybe five or six years of iPads under our belt where I review the iPad and I say the same thing that I said the last year when I reviewed the iPad, which is, man, this hardware is so good, so impressive, so thin, so fast, beautiful screen, but it\'s still an iPad. I always say that line, but it\'s still an iPad. And that\'s because it\'s still the same iOS on steroids kind of software where if you were hoping to make it your computer, it is clearly not up to that. It\'s not designed for that. And heck, it\'s Apple. Why would we expect them to do that? They make computers. If they wanted to sell you a computer, it\'s over there. It\'s called the Mac. So, they\'re always so separate for so long. And I\'ve watched so many YouTube\n\nit was a lot. It was quite a bit. I think it was enough to have some thoughts and some meat to chew on while we also wait for the rest of Apple intelligence stuff and more AI features. I think the way that they addressed it was actually very smart because they kind of took the like bad is forever and delay is temporary approach. Just saying like we want this to be good. We have quality standards. Just wait for it. I think that\'s always the best way to delay things honestly. Sure. Uh how it affects their stock price, I have no idea. It didn\'t do very well, I don\'t think, when it got announced. You know, that\'s how it is. Anyway, well, we could talk about any number of these 26 versions of OS first, but I think the one that most people want to talk about is iOS 26. So, we should probably just jump in there. So, liquid new Yeah, liquid liquid glass everywhere. Liquid glass is uh the new aesthetic that is specifically the transparent and refractive almost mater ...

# %%
final_prompt = prompt.invoke({"context": context_text, "question": question})

# %%
final_prompt
# Out:
# StringPromptValue(text='\n      You are a helpful assistant.\n      Answer ONLY from the provided transcript context.\n      If the context is insufficient, just say you don\'t know.\n\n      thing. It was kind of shocking. It was just teared up. Crazy. Like they did all they added full free form windows. Like you can just drag from the corner and make a bunch of windows as whatever size you want. uh multiple overlapping windows, oncreen, offscreen, full screen. They also added a menu bar at the top and window controls on those windows. And yeah, that the stoplight menu for like closing or minimizing or change the size of windows. There\'s a new redesigned files app. There is a new audio input selector, which I also confirmed will work with Bluetooth microphones. I used to have to I\'ve been paying for apps to do this for like years. Every time I test Bluetooth headphones, I\'m like, "How do I do this test? This is going to be the worst part." Yeah. Um, there are so many things in iPad OS. Uh, the pre the new preview app, you can export to different file sizes and types. Like all of this stuff, uh, the new files app can let you sort by or organize by showing different types\n\nfor me. So good. So those are nice. Uh, what else is new to iOS 26? Well, in the phone app, there\'s also a new phone app design. So it shows like there\'s now a contacts cards like favorites list at the top, which is nice. Um, yeah, they they redesigned it a little bit. It\'s a lot simpler. There\'s only like three things at the bottom now. And then a little search bar has the new uh liquid glass design. Uh and they also separated calls, miss calls, voicemails, spam into these little sub menus. So this is actually a theme throughout quite a bit of the OS where they have created these sub menus for things that you probably don\'t want to deal with. For example, segue into messages app. Uh in the messages, thank you. Very good. In the messages app, they\'ve also included this submen that really is the hamburger menu but tilted 90°. Uh, and when you click it, it also now has a unknown senders folder. Wait, what? Yeah, in the messages app for like hamburger menu tilted 90°. Oh, wait. No, it\'s\n\nSo, that\'s cood.io/wave and get six months of the team plan for free. cod.io/wave. All right, welcome back. We\'ve got one more big OS update to talk about from Apple this week and that is the iPad. Now, the history of iPad updates has been very consistent. We\'ve got maybe five or six years of iPads under our belt where I review the iPad and I say the same thing that I said the last year when I reviewed the iPad, which is, man, this hardware is so good, so impressive, so thin, so fast, beautiful screen, but it\'s still an iPad. I always say that line, but it\'s still an iPad. And that\'s because it\'s still the same iOS on steroids kind of software where if you were hoping to make it your computer, it is clearly not up to that. It\'s not designed for that. And heck, it\'s Apple. Why would we expect them to do that? They make computers. If they wanted to sell you a computer, it\'s over there. It\'s called the Mac. So, they\'re always so separate for so long. And I\'ve watched so many YouTube\n\nit was a lot. It was quite a bit. I think it was enough to have some thoughts and some meat to chew on while we also wait for the rest of Apple intelligence stuff and more AI features. I think the way that they addressed it was actually very smart because they kind of took the like bad is forever and delay is temporary approach. Just saying like we want this to be good. We have quality standards. Just wait for it. I think that\'s always the best way to delay things honestly. Sure. Uh how it affects their stock price, I have no idea. It didn\'t do very well, I don\'t think, when it got announced. You know, that\'s how it is. Anyway, well, we could talk about any number of these 26 versions of OS first, but I think the one that most people want to talk about is iOS 26. So, we ...

# %% [markdown]
# ### Step 4 - Generation

# %%
answer = model.invoke(final_prompt)
print(answer.content)
# Out:
# Apple released several features in their overhaul of iOS, including a redesigned phone app with a contacts cards favorites list at the top, a simpler interface with only three options at the bottom, and a new liquid glass design with submenus for calls, missed calls, voicemails, and spam. They also introduced a new preview app that allows exporting to different file sizes and types, a new files app that can organize by different types, and a new audio input selector that works with Bluetooth microphones. Additionally, there is a new menu bar at the top, window controls on windows, and a stoplight menu for closing, minimizing, or resizing windows.

# %% [markdown]
# ### Step 5 - Building a chain

# %%
from langchain_core.runnables import RunnableParallel, RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

# %%
def format_docs(retrieved_docs):
  context_text = "\n\n".join(doc.page_content for doc in retrieved_docs)
  return context_text

# %%
parallel_chain = RunnableParallel({
    'context': retriever | RunnableLambda(format_docs),
    'question': RunnablePassthrough()
})

# %%
parallel_chain.invoke('What is the next iOS called')
# Out:
# {'context': 'one cutout of like that\'s pretty good, but the more you look at it, the more blocky and like chopped off like old bad portrait mode. Yeah. Yeah. Wait, Marquez, could you drop that video in the Slack for the big ballers already uploading? Sweet. Yes. So, yeah, I guess we can we can talk about any number of these OSs. They are all labeled version 26 now. So if you were thinking, "Oh, this is only the third Vision OS." Oh, we know. It\'s just they call it Vision OS 26 now because they\'re all 26. We talked about this last week how it\'s feels futuristic even though it comes out during 2025. I mean, who doesn\'t want iOS 26 at WWDC2? Exactly. On the Galaxy S25 Ultra. Someone brought up an interesting point. Are they going to call the new iPhone the iPhone 26 now? cuz it\'s going to be a little awkward to have the iPhone 17 running iOS 26. They\'re going to call it the iPhone 9. Oh god. Well, we Well, it didn\'t match before though. Yeah. True. Yeah. I don\'t think they\'re going to. I don\'t think\n\nit was a lot. It was quite a bit. I think it was enough to have some thoughts and some meat to chew on while we also wait for the rest of Apple intelligence stuff and more AI features. I think the way that they addressed it was actually very smart because they kind of took the like bad is forever and delay is temporary approach. Just saying like we want this to be good. We have quality standards. Just wait for it. I think that\'s always the best way to delay things honestly. Sure. Uh how it affects their stock price, I have no idea. It didn\'t do very well, I don\'t think, when it got announced. You know, that\'s how it is. Anyway, well, we could talk about any number of these 26 versions of OS first, but I think the one that most people want to talk about is iOS 26. So, we should probably just jump in there. So, liquid new Yeah, liquid liquid glass everywhere. Liquid glass is uh the new aesthetic that is specifically the transparent and refractive almost material design of all of these\n\nSo, that\'s cood.io/wave and get six months of the team plan for free. cod.io/wave. All right, welcome back. We\'ve got one more big OS update to talk about from Apple this week and that is the iPad. Now, the history of iPad updates has been very consistent. We\'ve got maybe five or six years of iPads under our belt where I review the iPad and I say the same thing that I said the last year when I reviewed the iPad, which is, man, this hardware is so good, so impressive, so thin, so fast, beautiful screen, but it\'s still an iPad. I always say that line, but it\'s still an iPad. And that\'s because it\'s still the same iOS on steroids kind of software where if you were hoping to make it your computer, it is clearly not up to that. It\'s not designed for that. And heck, it\'s Apple. Why would we expect them to do that? They make computers. If they wanted to sell you a computer, it\'s over there. It\'s called the Mac. So, they\'re always so separate for so long. And I\'ve watched so many YouTube\n\nto have the iPhone 17 running iOS 26. They\'re going to call it the iPhone 9. Oh god. Well, we Well, it didn\'t match before though. Yeah. True. Yeah. I don\'t think they\'re going to. I don\'t think they will. Okay. So, I iPhone 17 iOS 26. We\'ll see. We should place this bet. No, we\'ll see. Uh yeah, I guess we\'ll start. Speaking of a bet. Yeah. What was our overunder last week for how many times they say? I think it was four 4.5 or something. and I said under. It turns out they said the word Siri times total during the entire 90minute presentation that main keynote. It was right off the riff and they it was right at the beginning and it was back to back and then they just didn\'t say the word again. They they like weirdly went here\'s all the things Apple intelligence brought and there was like this big list that looked really impressive at first but really it was a lot of very simple things. And then I have the quote here. It\'s just we in ...
#  'question': 'What is the next iOS called'}

# %%
parser = StrOutputParser()

# %%
main_chain = parallel_chain | prompt | model | parser

# %%
main_chain.invoke('What is next iOS called')
# Out:
# 'The next iOS is called iOS 26.'

# %% [markdown]
# ### Streamlit Implementation
